# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Resources

# %% [markdown]
# **Books (on Google Drive):**
#
# Introduction to Statistical Learning, chapters 4.1 and 4.2
#
# Hands on Machine Learning with scikit-learn and tensorflow, chapter 2
#
#
# **Scikit-learn doc:**
#
# https://scikit-learn.org/stable/
#
# https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html
#
# https://scikit-learn.org/stable/modules/cross_validation.html
#
#
# **Other resources:**
#
# https://www.youtube.com/watch?v=UqYde-LULfs
#
# https://neptune.ai/blog/f1-score-accuracy-roc-auc-pr-auc
#
# https://medium.com/30-days-of-machine-learning/day-3-k-nearest-neighbors-and-bias-variance-tradeoff-75f84d515bdb

# %% [markdown]
# # Classification with scikit-learn : predicting heart diseases with machine learning

# %% [markdown]
# ## The Heart disease dataset

# %% [markdown]
# For discovering classification, we're gonna use a rather classic dataset: the heart disease dataset. This dataset contains 13 symptoms and other attributes of patients that have been checked for a heart disease, such as their age, their cholesterol blood level, the type of pain they report, .... observed on 303 patients. These 13 attributes are called the *features*. And for each of these patients, we know if they have a heart disease or not: the field called *target* in the dataset. This field is generally called the *classes* of the problem, in this case we have two classes : 0 for healthy patients, and 1 for patients with a heart disease, hence it is called a *binary classification problem*.
#
# As with linear regression, we generally denote the feature matrix by $X$, and the classes with $y$, where, in this dataset:
#
#
# $$X \in \mathbb{R}^{303 \times 13}, y \in  \{0,1\}^{303}.$$
# The goal of classification is to learn a function, or *classifier*, $f$ that approximates the true classes $y$ from the features $X$:
#
#
# $$y \approx f(X).$$
#
# However as $y$ is categorical in classification problems since it represents different classes, as opposed to a continuous value as in linear regression, we cannot use linear regression for solving these problems, and we need different models.
#
# Also note that classification is not always binary, and can classify features between more than 2 classes (will not be covered today, but the models that we will use here can be directly used with any number of classes).
#
# To get a better idea of these concepts, read chapter 4.1 and 4.2 from the *Introduction to Statistical Learning* book.

# %% [markdown]
# First, let's load the dataset into a pandas DataFrame:

# %%
dataset = pd.read_csv('../data/heart.csv')

# %% [markdown]
# Let's have a look at the column and content:

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# Here are the 13 features, and the classes assignation column called here *target*. We can see that there is no missing values in the data, so far so good. Their names correspond to the following clinical observations:
#
# |Name |Type |	Description |
# |-----|-----|---------------|
# |age      |integer | age of patient |
# |sex      |integer | 1=male; 0=female |
# |cp       |integer | chest pain type: 0=typical angina; 1=atypical angine; 2=non-anginal pain; 3=asymptomatic |
# |trestbps |integer | resting blood pressure (mm Hg) |
# |chol     |integer | serum cholestrol (mg/dl) |
# |fbs      |integer | fasting blood sugar: 1 if > 120 mg/dl; 0 otherwise |
# |restecg  |integer | resting electrocardiographic results: 0=normal; 1=having ST-T wave abnormality; 2=showing probable or definite left ventricular hypertrophy |
# |thalach  |integer | maximum heart rate achieved |
# |exang    |integer | exercise induced angina: 1=yes; 0=no |
# |oldpeak  |float   | ST depression induced by exercise relative to rest |
# |slope    |integer | the slope of the peak exercise ST segment: 0=upsloping; 1=flat; 2=downsloping |
# |ca       |integer | number of major vessels (0-4) colored by flourosopy |
# |thal     |integer | 1=normal; 2=fixed defect; 3=reversable defect |
# |target      |integer | predicted attribute; 0=NO HEART DISEASE; 1=HEART DISEASE |
#
# Some of these features have continuous values such as *age* or *chol*, while others are categorical such as *cp* or *slope*. We will see that categorical variables need to be handled differently when preprocessing the data.
#
# This dataset is derived from : https://archive.ics.uci.edu/ml/datasets/Heart+Disease

# %% [markdown]
# ## Getting into the data

# %% [markdown]
# Let's now have a look of the distribution of the values of each columns:

# %%
dataset.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.326733    0.455446
# std      0.583020    0.498835
# min      1.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    0.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# We can see that the distribution of the features are different: the age vary from 29 to 77, whereas cholesterol rates from 126 to 564. To avoid some features to bias the classifier because they have larger values than others, we will need to center their means to 0 and scale their variance to 1 when preprocessing them.
# Let's now plot the histogram of each feature :

# %%
rcParams['figure.figsize'] = 16,12
plots = dataset.hist()

# %% [markdown]
# It is quite clear now that some of the features are categorical with peaks only at some value, whereas others are continuous.

# %% [markdown]
# Another important thing to check when performing classification is the balance between the target classes: is there as many samples (=patients) that are sick as there are healthy patient:

# %%
rcParams['figure.figsize'] = 8,6
plt.bar(dataset['target'].unique(), dataset['target'].value_counts(), color = ['red', 'green'])
plt.xticks([0, 1])
plt.xlabel('Target Classes')
plt.ylabel('Count')
plt.title('Count of each Target Class')
# Out:
# Text(0.5, 1.0, 'Count of each Target Class')

# %% [markdown]
# A too much imbalanced dataset can bias the classification model towards the class with more samples. Here we see that the two classes, healthy and having a heart diseased, are quite balanced in this dataset. (Some classification models allow for correcting this if needed, you can later have a look at : https://scikit-learn.org/stable/auto_examples/svm/plot_separating_hyperplane_unbalanced.html , but we won't need it today).

# %% [markdown]
# We can also plot the correlation matrix beween all the features and the target classes to get an idea of which features will probably be good predictors for our problem :

# %%
#Some correlate with target, others not
rcParams['figure.figsize'] = 20, 14
plt.matshow(dataset.corr())
plt.yticks(np.arange(dataset.shape[1]), dataset.columns)
plt.xticks(np.arange(dataset.shape[1]), dataset.columns)
plt.colorbar()

# %% [markdown]
# Here we can see that no single feature has a very high or very low correlation with the target value, meaning that the diagnostic is complex and will require a combination of all of these.

# %% [markdown]
# ## Preprocessing data

# %% [markdown]
# We have seen that we have categorical features, for example the *cp* feature that describes the chest pain type reported with number from 0 to 3:
# 0=typical angina; 1=atypical angina; 2=non-anginal pain; 3=asymptomatic.
#
# However these are *qualitative* categories, and there is no notion of distance between these numbers: an atypical angina is not 2 times a typical angina!
#
# To handle that we are going to create what we call *dummy variables*, that is, for each value 0, 1, 2, and 3, we are going to create a new feature which is a 0-1 feature only, and has a 1 value only for its own value. However we will do that only for *multicategorical* features : the ones that have more than two distinct values, since binary features like *sex*, *exang* and *fbs* are already 0-1 features.

# %%
multicategorical_features = ['cp', 'restecg', 'slope', 'ca', 'thal']
continuous_features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
dataset
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       0
# 1        0   0     2       0
# 2        2   0     2       0
# 3        2   0     2       0
# 4        2   0     2       0
# ..     ...  ..   ...     ...
# 298      1   0     3       1
# 299      1   0     3       1
# 300      1   2     3       1
# 301      1   1     3       1
# 302      1   1     2       1
#
# [303 rows x 14 columns]

# %%
dataset= pd.get_dummies(dataset, columns=multicategorical_features, dtype=int)

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'trestbps', 'chol', 'fbs', 'thalach', 'exang', 'oldpeak',
#        'target', 'cp_0', 'cp_1', 'cp_2', 'cp_3', 'restecg_0', 'restecg_1',
#        'restecg_2', 'slope_0', 'slope_1', 'slope_2', 'ca_0', 'ca_1', 'ca_2',
#        'ca_3', 'ca_4', 'thal_1', 'thal_2', 'thal_3'],
#       dtype='object')

# %%
dataset.sample(10)
# Out:
#      age  sex  trestbps  chol  fbs  thalach  exang  oldpeak  target  cp_0  \
# 120   64    0       130   303    0      122      0      2.0       0     1
# 282   59    1       126   218    1      134      0      2.2       1     0
# 61    54    1       108   309    0      156      0      0.0       0     0
# 119   46    0       138   243    0      152      1      0.0       0     1
# 238   77    1       125   304    0      162      1      0.0       1     1
# 37    54    1       150   232    0      165      0      1.6       0     0
# 253   67    1       100   299    0      125      1      0.9       1     1
# 39    65    0       160   360    0      151      0      0.8       0     0
# 21    44    1       130   233    0      179      1      0.4       0     0
# 222   65    1       138   282    1      174      0      1.4       1     0
#
#      ...  slope_1  slope_2  ca_0  ca_1  ca_2  ca_3  ca_4  thal_1  thal_2  \
# 120  ...        1        0     0     0     1     0     0       0       1
# 282  ...        1        0     0     1     0     0     0       1       0
# 61   ...        0        1     1     0     0     0     0       0       0
# 119  ...        1        0     1     0     0     0     0       0       1
# 238  ...        0        1     0     0     0     1     0       0       1
# 37   ...        0        1     1     0     0     0     0       0       0
# 253  ...        1        0     0     0     1     0     0       0       1
# 39   ...        0        1     1     0     0     0     0       0       1
# 21   ...        0        1     1     0     0     0     0       0       1
# 222  ...        1        0     0     1     0     0     0       0       1
#
#      thal_3
# 120       0
# 282       0
# 61        1
# 119       0
# 238       0
# 37        1
# 253       0
# 39        0
# 21        0
# 222       0
#
# [10 rows x 27 columns]

# %% [markdown]
# Let's now plot our new features to see the difference:

# %%
rcParams['figure.figsize'] = 16,12
plots = dataset.hist()

# %% [markdown]
# Let's now separate the features from the classes in an $X$ and $y$ variables:

# %%
#TO FILL
#Separate features and target 
y = dataset.target
X = dataset.drop(columns='target')

# %% [markdown]
# We've also said that we should center and scale our continuous variables to avoid biasing the classification model, use the *StandardScaler* class from scikit-learn to do so, after splitting the data set between train and test, to fit the scaler on the train set only :

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Split with a 30% test set, we stratify so that we have the same rate of positives
#in the training and test sets (as well as the same sex ratio, it will be useful at the end of the notebook)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 41, 
                                                    test_size = 0.3, 
                                                    stratify = pd.concat([dataset['sex'], y], axis = 1))

# %%
# Scaling continuous variables
from sklearn.preprocessing import StandardScaler

cat_cols = [ 'sex', 'fbs', 'exang', 'cp_0', 'cp_1', 'cp_2', 'cp_3', 'restecg_0', 'restecg_1', 'restecg_2',
       'slope_0', 'slope_1', 'slope_2', 'ca_0', 'ca_1', 'ca_2', 'ca_3', 'ca_4',
       'thal_1', 'thal_2', 'thal_3']
num_cols = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

X_train_num = X_train[num_cols]
X_train_cat = X_train[cat_cols]

X_test_num = X_test[num_cols]
X_test_cat = X_test[cat_cols]

# %%
scaler = StandardScaler()
X_train_num_scaled_array = scaler.fit_transform(X_train_num)
X_test_num_scaled_array = scaler.transform(X_test_num)

# %%
X_train_num_scaled = pd.DataFrame(X_train_num_scaled_array, columns=num_cols, index=X_train.index)
X_test_num_scaled = pd.DataFrame(X_test_num_scaled_array, columns=num_cols, index=X_test.index)
X_train_scaled = pd.concat([X_train_num_scaled, X_train_cat], axis=1)
X_test_scaled = pd.concat([X_test_num_scaled, X_test_cat], axis=1)

# %%
X_train_scaled
# Out:
#           age  trestbps      chol   thalach   oldpeak  sex  fbs  exang  cp_0  \
# 286  0.493857  0.140070 -0.789802  0.563027 -0.208840    1    0      0     0
# 115 -1.923087 -0.670315 -0.588025  0.919198 -0.889979    0    0      0     0
# 187 -0.055449 -0.438777  0.347485 -1.796605  0.983153    1    0      1     1
# 134 -1.483643 -0.323007  1.081219  0.607549 -0.889979    0    0      0     0
# 140 -0.385032 -0.670315  0.879442  0.340420 -0.379124    0    0      0     0
# ..        ...       ...       ...       ...       ...  ...  ...    ...   ...
# 216  0.823440 -0.091469  0.292455 -2.330861  0.131730    0    0      0     0
# 9    0.274135  1.066224 -1.450163  1.097284  0.472299    1    0      0     0
# 211  0.713579 -0.670315  0.237425 -0.416443  2.175146    1    0      1     1
# 65  -2.142810  0.371609 -1.175013  1.453455  0.302014    0    0      0     1
# 82   0.603718 -1.712239  1.301339  0.473985 -0.889979    0    0      0     0
#
#      cp_1  ...  slope_1  slope_2  ca_0  ca_1  ca_2  ca_3  ca_4  thal_1  \
# 286     0  ...        0        1     0     0     1     0     0       0
# 115     0  ...        0        1     1     0     0     0     0       0
# 187     0  ...        1        0     0     1     0     0     0       0
# 134     1  ...        0        1     1     0     0     0     0       0
# 140     0  ...        0        1     1     0     0     0     0       0
# ..    ...  ...      ...      ...   ...   ...   ...   ...   ...     ...
# 216     0  ...        1        0     0     1     0     0     0       0
# 9       0  ...        0        1     1     0     0     0     0       0
# 211     0  ...        1        0     0     1     0     0     0       0
# 65      0  ...        0        1     1     0     0     0     0       0
# 82      0  ...        0        1     0     1     0     0     0       0
#
#      thal_2  thal_3
# 286       1       0
# 115       1       0
# 187       0       1
# 134       1       0
# 140       1       0
# ..      ...     ...
# 216       0       1
# 9         1       0
# 211       0       1
# 65        1       0
# 82        1       0
#
# [212 rows x 26 columns]

# %% [markdown]
# Fill the memo.txt file to answer the following question:
#
# 1) What are the necessary preprocessing steps regarding:
#
# a) classes:
#
# b) categorical features:
#
# c) continuous features:

# %% [markdown]
# ## Classification with k-nearest neighbors, and classification metrics

# %% [markdown]
# One easy introduction to classification is to start with the k-neareast neighbors method (KNN). At training, it simply memorizes all the training samples features $X$ and classes $y$. At test time given the features of one sample $x'$, it identifies the $k$ training samples $x_i, i \in 1,\dots,k$ that are the closest to $x'$ (in euclidian distance), and assign the class $y'$ that is the most frequent among the k-neareast neighbor classes $y_i, i \in 1,\dots,k$.
#
# So each test sample is assigned a probablity, for example of having a heart disease:
#
#
# $$P(y' = 1 ) = \frac{1}{k} \sum_{ i \in 1,\dots,k} \mathbb{1}(y_i = 1) $$
#
# where the indicator function $\mathbb{1}(y_i = 1) = 1$ if $y_i = 1$, else $\mathbb{1}(y_i = 1) = 0$. So the probability of having a heart disease is the proportion of the k-nearest train samples that have a heart disease.
#
# For an intuitive explanation of KNNs, watch the first 1:45min of this vid (the rest of it that is about Voronoi partitions is not necessary): https://www.youtube.com/watch?v=UqYde-LULfs
#
# You can also read pages 38-40 from the *Introduction to Statistical Learning*.

# %% [markdown]
# Compute the predictions of a k-nearest neighbors classifier on the test set, with k=15 :

# %%
from sklearn.neighbors import KNeighborsClassifier

n_neighbors = 15

#TOFILL: 

knn_clf = KNeighborsClassifier(n_neighbors)
knn_clf.fit(X_train_scaled, y_train) 

y_test_pred = knn_clf.predict(X_test_scaled)

# %% [markdown]
# Use these predictions to compute the accuracy of your 15-nearest neighbors model :

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_test_pred)
# Out:
# 0.8131868131868132

# %% [markdown]
# $\approx$ 81%, pretty good for someone who doesn't know about medicine ! However accuracy is a quite limited view of the prediction abilities of your classifier. Indeed it doesn't make the difference between patients that have been incorrectly classified with a heart disease (because they were healthy) with patients that have been incorrectly classified as healthy (because they had a disease).
#
# Let's look at the *confusion matrix* of the prediction, it gives use the number of patients that have been correctly classified as having a disease : the *true positives* (TP) ; the number of patients that have been correctly classified as not having a disease : the *true negatives* (TN); the number of patients that have been incorrectly classified as having a disease : the *false positives* (FP) ; and the number of patients that have been incorrectly classified as nothaving a disease : the *false negatives* (FN). To remember more easily, remark that the true/false refers to the *true* class of the test samples, whereas the positive/negative refers to the *predicted* class by the classifier.
#
# The confusion matrix gives these four numbers in the following format:
#
# |  |  |
# |--|--|
# |TN|FP|
# |FN|TP|
#
# The accuracy is computed by :
#
#
# $$accuracy= \frac{TP + TN}{TP + TN + FP + FN}$$
#
# One can also look at the accuracy of positive predictions, called the *precision*:
#
#
# $$precision= \frac{TP }{TP + FP}$$
#
# Or at the ratio of positive samples correctly detected by the classifier, called the *recall*:
#
#
# $$recall= \frac{TP }{TP + FN}$$
#
#
# These two metrics are often grouped together as a single one called the *f1-measure*:
#
# $$F1=  2 \times \frac{precision \times recall}{precision + recall}$$
#
# You can read more about it in chapter 3 of the book *Hands on Machine Learning with scikit-learn and tensorflow*.
#
# So these metrics gives use different informations about our classifier predictive performances, we are gonna see in more details how below, first compute them on the results of your predictions :

# %%
from sklearn.metrics import confusion_matrix,  precision_score, recall_score, accuracy_score, f1_score

print(f" precision score : {precision_score(y_test, y_test_pred)}")
print(f" recall score : {recall_score(y_test, y_test_pred)}")
print(f" accuracy score : {accuracy_score(y_test, y_test_pred)}")
print(f" f1 score : {f1_score(y_test, y_test_pred)}")

plt.figure(figsize=(6,6))
sns.heatmap(confusion_matrix(y_test, y_test_pred), annot=True)

#toujours arg 1 : lignes et arg2 : colonnes dans la confusion matrix
# Out:
#  precision score : 0.8529411764705882
#  recall score : 0.7073170731707317
#  accuracy score : 0.8131868131868132
#  f1 score : 0.7733333333333333
# <Axes: >

# %% [markdown]
# Fill the memo.txt file to answer these questions:
#
# 2)a) How many patient were incorrectly diagnosed with a Heart disease ?
#
# 2)b) How many patient were incorrectly diagnosed as being Healthy ?

# %% [markdown]
# In general, remember that accuracy is more sensitive to class imbalance (which is not the case here as there is roughly as many positive as negative samples in the data), and that the f1 better summarizes balance between precision and recall. The f1 is preferred to accuracy when you care more about the positive class (which is our case).

# %% [markdown]
# ## The precision/recall trade-off

# %% [markdown]
# We have assessed some measures that are applicables to the predicted classes, i.e. 0 or 1. Remember that KNN assigns a probability to each test sample, and simply predicts 1 if this probability is higher than > 0.5:
#
#
# $$P(y' = 1 ) = \frac{1}{k} \sum_{ i \in 1,\dots,k} \mathbb{1}(y_i = 1)  > 0.5$$
#
#
# Let us say we are here performing a first diagnosis test with our classifier, for further medical investigation if the prediction is positive. In this context, it is much more important to not say someone is healthy if he is not, rather than saying someone is sick if he is not (which can be discovered with later medical tests). In other words, we want to have a few false negatives, even if that implies having more false positives. This means we'd prefer to have a higher Recall, to the cost of having a lower Precision. And that implies choosing a threshold that is lower than 0.5 for assigning the classes.

# %% [markdown]
# Use *predict_proba* to get the probability of each test sample, and print these probabilities:

# %%
#TOFILL
#Print the probability associated with y:
y_test_proba = knn_clf.predict_proba(X_test_scaled)
y_test_proba
# Out:
# array([[0.93333333, 0.06666667],
#        [0.        , 1.        ],
#        [0.86666667, 0.13333333],
#        [0.33333333, 0.66666667],
#        [0.2       , 0.8       ],
#        [0.26666667, 0.73333333],
#        [0.66666667, 0.33333333],
#        [0.06666667, 0.93333333],
#        [0.13333333, 0.86666667],
#        [0.06666667, 0.93333333],
#        [0.33333333, 0.66666667],
#        [0.93333333, 0.06666667],
#        [0.93333333, 0.06666667],
#        [0.33333333, 0.66666667],
#        [0.93333333, 0.06666667],
#        [0.4       , 0.6       ],
#        [0.86666667, 0.13333333],
#        [0.66666667, 0.33333333],
#        [0.06666667, 0.93333333],
#        [0.13333333, 0.86666667],
#        [1.        , 0.        ],
#        [0.93333333, 0.06666667],
#        [1.        , 0.        ],
#        [0.86666667, 0.13333333],
#        [1.        , 0.        ],
#        [0.8       , 0.2       ],
#        [0.        , 1.        ],
#        [0.        , 1.        ],
#        [0.        , 1.        ],
#        [1.        , 0.        ],
#        [0.86666667, 0.13333333],
#        [0.8       , 0.2       ],
#        [0.4       , 0.6       ],
#        [0.73333333, 0.26666667],
#        [0.8       , 0.2       ],
#        [0.8       , 0.2       ],
#        [0.        , 1.        ],
#        [0.93333333, 0.06666667],
#        [1.        , 0.        ],
#        [1.        , 0.        ],
#        [0.66666667, 0.33333333],
#        [0.        , 1.        ],
#        [0.73333333, 0.26666667],
#        [0.93333333, 0.06666667],
#        [0.26666667, 0.73333333],
#        [0.4       , 0.6       ],
#        [1.        , 0.        ],
#        [0.33333333, 0.66666667],
#        [0.93333333, 0.06666667],
#        [1.        , 0.        ],
#        [0.86666667, 0.13333333],
#        [0.06666667, 0.93333333],
#        [0.66666667, 0.33333333],
#        [1.        , 0.        ],
#        [0.46666667, 0.53333333],
#        [0.06666667, 0.93333333],
#        [0.53333333, 0.46666667],
#        [0.8       , 0.2       ],
#        [0.86666667, 0.13333333],
#        [0.73333333, 0.26666667],
#        [0.93333333, 0.06666667],
#        [0.4       , 0.6       ],
#        [0.93333333, 0.06666667],
#        [0.73333333, 0.26666667],
#        [0.53333333, 0.46666667],
#        [0.06666667, 0.93333333],
#        [0.93333333, 0.06666667],
#        [0.4       , 0.6       ],
#        [0.66666667, 0.33333333],
#        [0.86666667, 0.13333333],
#        [0.73333333, 0.26666667],
#        [0.93333333, 0.06666667],
#        [0.06666667, 0.93333333],
#        [0.4       , 0.6       ],
#        [1.        , 0.        ],
#        [0.86666667, 0.13333333],
#        [0.06666667, 0.93333333],
#        [0.6       , 0.4       ],
#        [0.13333333, 0.86666667],
#        [0.93333333, 0.06666667],
#        [0.93333333, 0.06666667],
#        [0.93333333, 0.06666667],
#        [0.53333333, 0.46666667],
#        [0.6       , 0.4       ],
#        [0.        , 1.        ],
#        [0.86666667, 0.13333333],
#        [0.6       , 0.4       ],
#        [0.86666667, 0.13333333],
#        [0.93333333, 0.06666667],
#        [0.        , 1.        ],
#        [0.26666667, 0.73333333]])

# %% [markdown]
# `y_test_proba` should be a vector of probabilities of being positive of all samples, now let's check that if we apply a 0.5 threshold, we obtain the same predictions as before:

# %%
#By default KNN applies a 0.5 threshold to make its predictions:
((y_test_proba[:, 1] > 0.5).astype(int) == y_test_pred).all()
# associé la classe 1 = malade dès qu'on a une proba > à 0.5
# Out:
# np.True_

# %% [markdown]
# Let's plot the different values of Precision and Recall for different thresholds:

# %%
#Precision recall tradeoff
from sklearn.metrics import precision_recall_curve

def plot_precision_recall_vs_threshold(precisions, recalls, thresholds):
    plt.plot(thresholds, precisions[:-1], "b--", label="Precision")
    plt.plot(thresholds, recalls[:-1], "g-", label="Recall")
    plt.xlabel("Threshold")
    plt.legend(loc="upper left")
    plt.ylim([0, 1])

# %%
plt.figure(figsize=(12,6))
precisions, recalls, thresholds = precision_recall_curve(y_test, (y_test_proba[:, 1]))
plot_precision_recall_vs_threshold(precisions, recalls, thresholds)

# %% [markdown]
# As we can see, the lower the probability threshold, the higher the recall and the lower the precision. There is always a cost: this is what is called the precision/recall tradeoff. A classic way of seeing that is to plot the so-called precision-recall curve, with recall as abcissa and precision in ordinate. Plot it :

# %%
def plot_precision_recall_curve(precisions, recalls):
    plt.step(recalls, precisions, linewidth=2)
    plt.xlabel('Recall')
    plt.ylabel('Precision')

plot_precision_recall_curve(precisions, recalls)

# %% [markdown]
# Here again, we can see the precision/recall trade-off. The better the classifier is, the closer the curve will be to the top-right corner. One way to summarize all these trade-offs in a single metric is to compute the area under the precision-recall curve, also called the *average precision* :

# %%
from sklearn.metrics import average_precision_score

average_precision_score(y_test, (y_test_proba[:, 1]))
# Out:
# 0.8569688081636231

# %% [markdown]
# The average precision is generally the preferred metric if you can compute your test samples probabiliies, and if you care more about the positive class and/or have an imbalanced dataset.

# %% [markdown]
# So, let's not forget we are trying to diagnose people's heart disease. Let's say we are ready to accept to incorrectly label as healthy at most 5% of the patients that have a heart disease (false negatives), i.e. we want a recall of 0.95.
# Given the threshold curve above, choose a threshold that approximately yields a recall of 0.95, and recompute the confusion matrix as well as precision:

# %%
#TOFILL
threshold = 0.05
y_cv_pred_95recall = y_test_proba[:, 1] > threshold

print(f"precision :  {precision_score(y_test, y_cv_pred_95recall)}")
print(f"recall : {recall_score(y_test, y_cv_pred_95recall)}")

plt.figure(figsize=(6,6))
sns.heatmap(confusion_matrix(y_test, y_cv_pred_95recall), annot=True)
# Out:
# precision :  0.48148148148148145
# recall : 0.9512195121951219
# <Axes: >

# %% [markdown]
# Fill the memo.txt file to answer these two questions:
#
# 3)a)What is the precision if we change the threshold to have a 0.95 recall ?
#
# b) How many patient were incorrectly diagnosed as being Healthy (false negatives)?

# %% [markdown]
# ## The Receiver Operating Characteristic (ROC) curve

# %% [markdown]
# (Yet) another way to look at your classfier performance, is to consider the false positive rate (FPR) instead of precision:
#
#
# $$FPR= \frac{FP}{FP + TN}$$
#
# This is the proportion of negative test samples that are incorrectly classified as positive. Plotting the FPR against the recall gives another classic evaluation curve, the ROC curve.

# %%
#The ROC curve
from sklearn.metrics import roc_curve

def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([0, 1, 0, 1])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate (=Recall)')


plt.figure(figsize=(6,6))

fpr, tpr, threshold = roc_curve(y_test, y_cv_pred_95recall)
plot_roc_curve(fpr, tpr, label='seuil = 0,005')


fpr, tpr, threshold = roc_curve(y_test, (y_test_proba[:, 1] > 0.5).astype(int))
plot_roc_curve(fpr, tpr, label='seuil = 0,5')

plt.legend()

# %% [markdown]
# Here again there is a trade-off between TPR and FPR. Again, we can compute the area under this curve (AUC) :

# %%
from sklearn.metrics import roc_auc_score
print(f'seuil 0.05, auc score : {roc_auc_score(y_test, y_cv_pred_95recall)}')
print(f'seuil 0.5, auc score : {roc_auc_score(y_test, y_test_pred)}')
# Out:
# seuil 0.05, auc score : 0.555609756097561
# seuil 0.5, auc score : 0.8036585365853659

# %% [markdown]
# The ROC-AUC is useful when you can compute your test samples probabilities and care about how well ranked are your predictions, but it should be used when you have a balanced dataset and care equally about both targets, so we won't use it in the following because we care more about the positive class.

# %% [markdown]
# If you want to know more about all classification metrics and when to use them, you can read : https://neptune.ai/blog/f1-score-accuracy-roc-auc-pr-auc

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_test_pred))
print(classification_report(y_test, y_cv_pred_95recall)) #seuil du recall à 95 soit 0.05
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84        50
#            1       0.85      0.71      0.77        41
#
#     accuracy                           0.81        91
#    macro avg       0.82      0.80      0.81        91
# weighted avg       0.82      0.81      0.81        91
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.16      0.27        50
#            1       0.48      0.95      0.64        41
#
#     accuracy                           0.52        91
#    macro avg       0.64      0.56      0.45        91
# weighted avg       0.66      0.52      0.43        91

# %% [markdown]
# Fill the memo.txt file to answer the following questions:
#
# a) If I can compute my test sample probabilities and care more about the positive class, which overall metric should I use to compare classifiers ?
#
# b) And if I only have the class predictions and no probabilities ?

# %% [markdown]
# ## Hyper-parameters search : the best number of neighbors

# %% [markdown]
# Now we know that in our case (we care more about the people who are sick, i.e. the positive class), the best way to compare classifiers with a single metric is *average precision* (AP), so we can start choosing the best hyper-parameter k. You have already studied the bias/variance tradeoff with linear regression. Here this is the same: with k=1 the bias will be 0, but the variance very high, and conversely with too high a k. In both cases, we will have a sub-optimal AP.
#
# You can read more about the bias/variance trade-off with KNNs here: https://medium.com/30-days-of-machine-learning/day-3-k-nearest-neighbors-and-bias-variance-tradeoff-75f84d515bdb
#
#
# Let's search for the value of k that gives the best AP score, by doing a grid-search as you already did with linear regression, but first lets play a bit with the value of k. As you have already learnt, to choose the best hyper-parameters, we leave the test set aside, and do a *cross-validation* on the train set, from which we can compute *validation metrics* for each hyper-parameter combination to select them. You can remind yourself about cross-validation here:
#
# https://scikit-learn.org/stable/modules/cross_validation.html

# %% [markdown]
# Plot the PR curve and compute the mean validation APs with k=15, 30 and 50 by doing a 5-fold cross-validation over the training set :

# %%
from sklearn.model_selection import cross_val_predict

liste_k= [15,30,50]
for k in liste_k: 
    cross_val_predictions = cross_val_predict(KNeighborsClassifier(k), 
                                              X_train_scaled, 
                                              y_train , 
                                              cv = 5, 
                                                method='predict_proba')
    print(f" pour k:{k}, average_precision_score train : {average_precision_score(y_train,
                                                                            cross_val_predictions[:, 1])}")
# Out:
#  pour k:15, average_precision_score train : 0.8650388167983445
#  pour k:30, average_precision_score train : 0.8777083555045667
#  pour k:50, average_precision_score train : 0.8867858588703598

# %%
plt.figure(figsize=(12,6))
precisions, recalls, thresholds = precision_recall_curve(y_train, (cross_val_predictions[:, 1]))
plot_precision_recall_vs_threshold(precisions, recalls, thresholds)

# %% [markdown]
# To automatically select the k value that yields the best mean validation AP, use the *GridSearchCV* class to perform a grid search by doing a 5-fold cross validation on the train set with k ranging froom 0 to 100, and print the best mean AP on the cross validation and the best k value:

# %%
#Grid search k and give its roc auc score:
from sklearn.model_selection import GridSearchCV

k_range = range(1,101)
param_grid =  {'n_neighbors': k_range}
knn_clf = KNeighborsClassifier()

best_model_KNN = GridSearchCV(knn_clf, param_grid, cv=5, scoring='average_precision', 
                             return_train_score=True,
                             verbose=10)

best_model_KNN.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5; 1/100] START n_neighbors=1.............................................
# [CV 1/5; 1/100] END n_neighbors=1;, score=(train=1.000, test=0.792) total time=   0.0s
# [CV 2/5; 1/100] START n_neighbors=1.............................................
# [CV 2/5; 1/100] END n_neighbors=1;, score=(train=1.000, test=0.630) total time=   0.0s
# [CV 3/5; 1/100] START n_neighbors=1.............................................
# [CV 3/5; 1/100] END n_neighbors=1;, score=(train=1.000, test=0.566) total time=   0.0s
# [CV 4/5; 1/100] START n_neighbors=1.............................................
# [CV 4/5; 1/100] END n_neighbors=1;, score=(train=1.000, test=0.640) total time=   0.0s
# [CV 5/5; 1/100] START n_neighbors=1.............................................
# [CV 5/5; 1/100] END n_neighbors=1;, score=(train=1.000, test=0.612) total time=   0.0s
# [CV 1/5; 2/100] START n_neighbors=2.............................................
# [CV 1/5; 2/100] END n_neighbors=2;, score=(train=0.915, test=0.835) total time=   0.0s
# [CV 2/5; 2/100] START n_neighbors=2.............................................
# [CV 2/5; 2/100] END n_neighbors=2;, score=(train=0.925, test=0.829) total time=   0.0s
# [CV 3/5; 2/100] START n_neighbors=2.............................................
# [CV 3/5; 2/100] END n_neighbors=2;, score=(train=0.935, test=0.629) total time=   0.0s
# [CV 4/5; 2/100] START n_neighbors=2.............................................
# [CV 4/5; 2/100] END n_neighbors=2;, score=(train=0.927, test=0.760) total time=   0.0s
# [CV 5/5; 2/100] START n_neighbors=2.............................................
# [CV 5/5; 2/100] END n_neighbors=2;, score=(train=0.937, test=0.748) total time=   0.0s
# [CV 1/5; 3/100] START n_neighbors=3.............................................
# [CV 1/5; 3/100] END n_neighbors=3;, score=(train=0.920, test=0.843) total time=   0.0s
# [CV 2/5; 3/100] START n_neighbors=3.............................................
# [CV 2/5; 3/100] END n_neighbors=3;, score=(train=0.928, test=0.920) total time=   0.0s
# [CV 3/5; 3/100] START n_neighbors=3.............................................
# [CV 3/5; 3/100] END n_neighbors=3;, score=(train=0.954, test=0.757) total time=   0.0s
# [CV 4/5; 3/100] START n_neighbors=3.............................................
# [CV 4/5; 3/100] END n_neighbors=3;, score=(train=0.934, test=0.900) total time=   0.0s
# [CV 5/5; 3/100] START n_neighbors=3.............................................
# [CV 5/5; 3/100] END n_neighbors=3;, score=(train=0.930, test=0.781) total time=   0.0s
# [CV 1/5; 4/100] START n_neighbors=4.............................................
# [CV 1/5; 4/100] END n_neighbors=4;, score=(train=0.929, test=0.852) total time=   0.0s
# [CV 2/5; 4/100] START n_neighbors=4.............................................
# [CV 2/5; 4/100] END n_neighbors=4;, score=(train=0.917, test=0.899) total time=   0.0s
# [CV 3/5; 4/100] START n_neighbors=4.............................................
# [CV 3/5; 4/100] END n_neighbors=4;, score=(train=0.947, test=0.788) total time=   0.0s
# [CV 4/5; 4/100] START n_neighbors=4.............................................
# [CV 4/5; 4/100] END n_neighbors=4;, score=(train=0.930, test=0.881) total time=   0.0s
# [CV 5/5; 4/100] START n_neighbors=4.............................................
# [CV 5/5; 4/100] END n_neighbors=4;, score=(train=0.939, test=0.774) total time=   0.0s
# [CV 1/5; 5/100] START n_neighbors=5.............................................
# [CV 1/5; 5/100] END n_neighbors=5;, score=(train=0.931, test=0.884) total time=   0.0s
# [CV 2/5; 5/100] START n_neighbors=5.............................................
# [CV 2/5; 5/100] END n_neighbors=5;, score=(train=0.910, test=0.910) total time=   0.0s
# [CV 3/5; 5/100] START n_neighbors=5.............................................
# [CV 3/5; 5/100] END n_neighbors=5;, score=(train=0.937, test=0.844) total time=   0.0s
# [CV 4/5; 5/100] START n_neighbors=5.............................................
# [CV 4/5; 5/100] END n_neighbors=5;, score=(train=0.927, test=0.915) total time=   0.0s
# [CV 5/5; 5/100] START n_neighbors=5.............................................
# [CV 5/5; 5/100] END n_neighbors=5;, score=(train=0.936, test=0.806) total time=   0.0s
# [CV 1/5; 6/100] START n_neighbors=6.............................................
# [CV 1/5; 6/100] END n_neighbors=6;, score=(train=0.930, test=0.887) total time=   0.0s
# [CV 2/5; 6/100] START n_neighbors=6.............................................
# [CV 2/5; 6/100] END n_neighbors=6;, score=(train=0.919, test=0.912) total time=   0.0s
# [CV 3/5; 6/100] START n_neighbors=6.............................................
# [CV 3/5; 6/100] END n_neighbors=6;, score=(train=0.930, test=0.864) total time=   0.0s
# [CV 4/5; 6/100] START n_neighbors=6.............................................
# [CV 4/5; 6/100] END n_neighbors=6;, score=(train=0.930, test=0.918) total time=   0.0s
# [CV 5/5; 6/100] START n_neighbors=6.............................................
# [CV 5/5; 6/100] END n_neighbors=6;, score=(train=0.931, test=0.803) total time=   0.0s
# [CV 1/5; 7/100] START n_neighbors=7.............................................
# [CV 1/5; 7/100] END n_neighbors=7;, score=(train=0.924, test=0.879) total time=   0.0s
# [CV 2/5; 7/100] START n_neighbors=7.............................................
# [CV 2/5; 7/100] END n_neighbors=7;, score=(train=0.907, test=0.912) total time=   0.0s
# [CV 3/5; 7/100] START n_neighbors=7.............................................
# [CV 3/5; 7/100] END n_neighbors=7;, score=(train=0.926, test=0.860) total time=   0.0s
# [CV 4/5; 7/100] START n_neighbors=7.............................................
# [CV 4/5; 7/100] END n_neighbors=7;, score=(train=0.914, test=0.934) total time=   0.0s
# [CV 5/5; 7/100] START n_neighbors=7.............................................
# [CV 5/5; 7/100] END n_neighbors=7;, score=(train=0.935, test=0.772) total time=   0.0s
# [CV 1/5; 8/100] START n_neighbors=8.............................................
# [CV 1/5; 8/100] END n_neighbors=8;, score=(train=0.924, test=0.890) total time=   0.0s
# [CV 2/5; 8/100] START n_neighbors=8.............................................
# [CV 2/5; 8/100] END n_neighbors=8;, score=(train=0.900, test=0.906) total time=   0.0s
# [CV 3/5; 8/100] START n_neighbors=8.............................................
# [CV 3/5; 8/100] END n_neighbors=8;, score=(train=0.922, test=0.856) total time=   0.0s
# [CV 4/5; 8/100] START n_neighbors=8.............................................
# [CV 4/5; 8/100] END n_neighbors=8;, score=(train=0.913, test=0.924) total time=   0.0s
# [CV 5/5; 8/100] START n_neighbors=8.............................................
# [CV 5/5; 8/100] END n_neighbors=8;, score=(train=0.934, test=0.769) total time=   0.0s
# [CV 1/5; 9/100] START n_neighbors=9.............................................
# [CV 1/5; 9/100] END n_neighbors=9;, score=(train=0.918, test=0.899) total time=   0.0s
# [CV 2/5; 9/100] START n_neighbors=9.............................................
# [CV 2/5; 9/100] END n_neighbors=9;, score=(train=0.907, test=0.912) total time=   0.0s
# [CV 3/5; 9/100] START n_neighbors=9.............................................
# [CV 3/5; 9/100] END n_neighbors=9;, score=(train=0.914, test=0.852) total time=   0.0s
# [CV 4/5; 9/100] START n_neighbors=9.............................................
# [CV 4/5; 9/100] END n_neighbors=9;, score=(train=0.910, test=0.928) total time=   0.0s
# [CV 5/5; 9/100] START n_neighbors=9.............................................
# [CV 5/5; 9/100] END n_neighbors=9;, score=(train=0.924, test=0.764) total time=   0.0s
# [CV 1/5; 10/100] START n_neighbors=10...........................................
# [CV 1/5; 10/100] END n_neighbors=10;, score=(train=0.923, test=0.903) total time=   0.0s
# [CV 2/5; 10/100] START n_neighbors=10...........................................
# [CV 2/5; 10/100] END n_neighbors=10;, score=(train=0.905, test=0.919) total time=   0.0s
# [CV 3/5; 10/100] START n_neighbors=10...........................................
# [CV 3/5; 10/100] END n_neighbors=10;, score=(train=0.910, test=0.865) total time=   0.0s
# [CV 4/5; 10/100] START n_neighbors=10...........................................
# [CV 4/5; 10/100] END n_neighbors=10;, score=(train=0.901, test=0.939) total time=   0.0s
# [CV 5/5; 10/100] START n_neighbors=10...........................................
# [CV 5/5; 10/100] END n_neighbors=10;, score=(train=0.921, test=0.754) total time=   0.0s
# [CV 1/5; 11/100] START n_neighbors=11...........................................
# [CV 1/5; 11/100] END n_neighbors=11;, score=(train=0.911, test=0.897) total time=   0.0s
# [CV 2/5; 11/100] START n_neighbors=11...........................................
# [CV 2/5; 11/100] END n_neighbors=11;, score=(train=0.901, test=0.934) total time=   0.0s
# [CV 3/5; 11/100] START n_neighbors=11...........................................
# [CV 3/5; 11/100] END n_neighbors=11;, score=(train=0.907, test=0.870) total time=   0.0s
# [CV 4/5; 11/100] START n_neighbors=11...........................................
# [CV 4/5; 11/100] END n_neighbors=11;, score=(train=0.904, test=0.936) total time=   0.0s
# [CV 5/5; 11/100] START n_neighbors=11...........................................
# [CV 5/5; 11/100] END n_neighbors=11;, score=(train=0.922, test=0.758) total time=   0.0s
# [CV 1/5; 12/100] START n_neighbors=12...........................................
# [CV 1/5; 12/100] END n_neighbors=12;, score=(train=0.905, test=0.897) total time=   0.0s
# [CV 2/5; 12/100] START n_neighbors=12...........................................
# [CV 2/5; 12/100] END n_neighbors=12;, score=(train=0.895, test=0.940) total time=   0.0s
# [CV 3/5; 12/100] START n_neighbors=12...........................................
# [CV 3/5; 12/100] END n_neighbors=12;, score=(train=0.904, test=0.868) total time=   0.0s
# [CV 4/5; 12/100] START n_neighbors=12...........................................
# [CV 4/5; 12/100] END n_neighbors=12;, score=(train=0.900, test=0.917) total time=   0.0s
# [CV 5/5; 12/100] START n_neighbors=12...........................................
# [CV 5/5; 12/100] END n_neighbors=12;, score=(train=0.923, test=0.767) total time=   0.0s
# [CV 1/5; 13/100] START n_neighbors=13...........................................
# [CV 1/5; 13/100] END n_neighbors=13;, score=(train=0.904, test=0.885) total time=   0.0s
# [CV 2/5; 13/100] START n_neighbors=13...........................................
# [CV 2/5; 13/100] END n_neighbors=13;, score=(train=0.893, test=0.932) total time=   0.0s
# [CV 3/5; 13/100] START n_neighbors=13...........................................
# [CV 3/5; 13/100] END n_neighbors=13;, score=(train=0.901, test=0.878) total time=   0.0s
# [CV 4/5; 13/100] START n_neighbors=13...........................................
# [CV 4/5; 13/100] END n_neighbors=13;, score=(train=0.893, test=0.919) total time=   0.0s
# [CV 5/5; 13/100] START n_neighbors=13...........................................
# [CV 5/5; 13/100] END n_neighbors=13;, score=(train=0.921, test=0.753) total time=   0.0s
# [CV 1/5; 14/100] START n_neighbors=14...........................................
# [CV 1/5; 14/100] END n_neighbors=14;, score=(train=0.902, test=0.872) total time=   0.0s
# [CV 2/5; 14/100] START n_neighbors=14...........................................
# [CV 2/5; 14/100] END n_neighbors=14;, score=(train=0.883, test=0.929) total time=   0.0s
# [CV 3/5; 14/100] START n_neighbors=14...........................................
# [CV 3/5; 14/100] END n_neighbors=14;, score=(train=0.897, test=0.888) total time=   0.0s
# [CV 4/5; 14/100] START n_neighbors=14...........................................
# [CV 4/5; 14/100] END n_neighbors=14;, score=(train=0.887, test=0.922) total time=   0.0s
# [CV 5/5; 14/100] START n_neighbors=14...........................................
# [CV 5/5; 14/100] END n_neighbors=14;, score=(train=0.916, test=0.748) total time=   0.0s
# [CV 1/5; 15/100] START n_neighbors=15...........................................
# [CV 1/5; 15/100] END n_neighbors=15;, score=(train=0.901, test=0.877) total time=   0.0s
# [CV 2/5; 15/100] START n_neighbors=15...........................................
# [CV 2/5; 15/100] END n_neighbors=15;, score=(train=0.884, test=0.936) total time=   0.0s
# [CV 3/5; 15/100] START n_neighbors=15...........................................
# [CV 3/5; 15/100] END n_neighbors=15;, score=(train=0.896, test=0.897) total time=   0.0s
# [CV 4/5; 15/100] START n_neighbors=15...........................................
# [CV 4/5; 15/100] END n_neighbors=15;, score=(train=0.887, test=0.912) total time=   0.0s
# [CV 5/5; 15/100] START n_neighbors=15...........................................
# [CV 5/5; 15/100] END n_neighbors=15;, score=(train=0.915, test=0.759) total time=   0.0s
# [CV 1/5; 16/100] START n_neighbors=16...........................................
# [CV 1/5; 16/100] END n_neighbors=16;, score=(train=0.902, test=0.864) total time=   0.0s
# [CV 2/5; 16/100] START n_neighbors=16...........................................
# [CV 2/5; 16/100] END n_neighbors=16;, score=(train=0.886, test=0.927) total time=   0.0s
# [CV 3/5; 16/100] START n_neighbors=16...........................................
# [CV 3/5; 16/100] END n_neighbors=16;, score=(train=0.894, test=0.890) total time=   0.0s
# [CV 4/5; 16/100] START n_neighbors=16...........................................
# [CV 4/5; 16/100] END n_neighbors=16;, score=(train=0.889, test=0.922) total time=   0.0s
# [CV 5/5; 16/100] START n_neighbors=16...........................................
# [CV 5/5; 16/100] END n_neighbors=16;, score=(train=0.914, test=0.798) total time=   0.0s
# [CV 1/5; 17/100] START n_neighbors=17...........................................
# [CV 1/5; 17/100] END n_neighbors=17;, score=(train=0.899, test=0.865) total time=   0.0s
# [CV 2/5; 17/100] START n_neighbors=17...........................................
# [CV 2/5; 17/100] END n_neighbors=17;, score=(train=0.887, test=0.930) total time=   0.0s
# [CV 3/5; 17/100] START n_neighbors=17...........................................
# [CV 3/5; 17/100] END n_neighbors=17;, score=(train=0.897, test=0.885) total time=   0.0s
# [CV 4/5; 17/100] START n_neighbors=17...........................................
# [CV 4/5; 17/100] END n_neighbors=17;, score=(train=0.894, test=0.922) total time=   0.0s
# [CV 5/5; 17/100] START n_neighbors=17...........................................
# [CV 5/5; 17/100] END n_neighbors=17;, score=(train=0.914, test=0.794) total time=   0.0s
# [CV 1/5; 18/100] START n_neighbors=18...........................................
# [CV 1/5; 18/100] END n_neighbors=18;, score=(train=0.897, test=0.871) total time=   0.0s
# [CV 2/5; 18/100] START n_neighbors=18...........................................
# [CV 2/5; 18/100] END n_neighbors=18;, score=(train=0.886, test=0.939) total time=   0.0s
# [CV 3/5; 18/100] START n_neighbors=18...........................................
# [CV 3/5; 18/100] END n_neighbors=18;, score=(train=0.893, test=0.875) total time=   0.0s
# [CV 4/5; 18/100] START n_neighbors=18...........................................
# [CV 4/5; 18/100] END n_neighbors=18;, score=(train=0.894, test=0.920) total time=   0.0s
# [CV 5/5; 18/100] START n_neighbors=18...........................................
# [CV 5/5; 18/100] END n_neighbors=18;, score=(train=0.912, test=0.788) total time=   0.0s
# [CV 1/5; 19/100] START n_neighbors=19...........................................
# [CV 1/5; 19/100] END n_neighbors=19;, score=(train=0.899, test=0.876) total time=   0.0s
# [CV 2/5; 19/100] START n_neighbors=19...........................................
# [CV 2/5; 19/100] END n_neighbors=19;, score=(train=0.883, test=0.927) total time=   0.0s
# [CV 3/5; 19/100] START n_neighbors=19...........................................
# [CV 3/5; 19/100] END n_neighbors=19;, score=(train=0.895, test=0.867) total time=   0.0s
# [CV 4/5; 19/100] START n_neighbors=19...........................................
# [CV 4/5; 19/100] END n_neighbors=19;, score=(train=0.894, test=0.921) total time=   0.0s
# [CV 5/5; 19/100] START n_neighbors=19...........................................
# [CV 5/5; 19/100] END n_neighbors=19;, score=(train=0.913, test=0.792) total time=   0.0s
# [CV 1/5; 20/100] START n_neighbors=20...........................................
# [CV 1/5; 20/100] END n_neighbors=20;, score=(train=0.897, test=0.876) total time=   0.0s
# [CV 2/5; 20/100] START n_neighbors=20...........................................
# [CV 2/5; 20/100] END n_neighbors=20;, score=(train=0.885, test=0.927) total time=   0.0s
# [CV 3/5; 20/100] START n_neighbors=20...........................................
# [CV 3/5; 20/100] END n_neighbors=20;, score=(train=0.888, test=0.870) total time=   0.0s
# [CV 4/5; 20/100] START n_neighbors=20...........................................
# [CV 4/5; 20/100] END n_neighbors=20;, score=(train=0.899, test=0.919) total time=   0.0s
# [CV 5/5; 20/100] START n_neighbors=20...........................................
# [CV 5/5; 20/100] END n_neighbors=20;, score=(train=0.909, test=0.807) total time=   0.0s
# [CV 1/5; 21/100] START n_neighbors=21...........................................
# [CV 1/5; 21/100] END n_neighbors=21;, score=(train=0.898, test=0.871) total time=   0.0s
# [CV 2/5; 21/100] START n_neighbors=21...........................................
# [CV 2/5; 21/100] END n_neighbors=21;, score=(train=0.885, test=0.926) total time=   0.0s
# [CV 3/5; 21/100] START n_neighbors=21...........................................
# [CV 3/5; 21/100] END n_neighbors=21;, score=(train=0.886, test=0.872) total time=   0.0s
# [CV 4/5; 21/100] START n_neighbors=21...........................................
# [CV 4/5; 21/100] END n_neighbors=21;, score=(train=0.899, test=0.921) total time=   0.0s
# [CV 5/5; 21/100] START n_neighbors=21...........................................
# [CV 5/5; 21/100] END n_neighbors=21;, score=(train=0.907, test=0.788) total time=   0.0s
# [CV 1/5; 22/100] START n_neighbors=22...........................................
# [CV 1/5; 22/100] END n_neighbors=22;, score=(train=0.895, test=0.892) total time=   0.0s
# [CV 2/5; 22/100] START n_neighbors=22...........................................
# [CV 2/5; 22/100] END n_neighbors=22;, score=(train=0.888, test=0.928) total time=   0.0s
# [CV 3/5; 22/100] START n_neighbors=22...........................................
# [CV 3/5; 22/100] END n_neighbors=22;, score=(train=0.889, test=0.869) total time=   0.0s
# [CV 4/5; 22/100] START n_neighbors=22...........................................
# [CV 4/5; 22/100] END n_neighbors=22;, score=(train=0.892, test=0.923) total time=   0.0s
# [CV 5/5; 22/100] START n_neighbors=22...........................................
# [CV 5/5; 22/100] END n_neighbors=22;, score=(train=0.908, test=0.792) total time=   0.0s
# [CV 1/5; 23/100] START n_neighbors=23...........................................
# [CV 1/5; 23/100] END n_neighbors=23;, score=(train=0.892, test=0.888) total time=   0.0s
# [CV 2/5; 23/100] START n_neighbors=23...........................................
# [CV 2/5; 23/100] END n_neighbors=23;, score=(train=0.884, test=0.923) total time=   0.0s
# [CV 3/5; 23/100] START n_neighbors=23...........................................
# [CV 3/5; 23/100] END n_neighbors=23;, score=(train=0.893, test=0.860) total time=   0.0s
# [CV 4/5; 23/100] START n_neighbors=23...........................................
# [CV 4/5; 23/100] END n_neighbors=23;, score=(train=0.887, test=0.928) total time=   0.0s
# [CV 5/5; 23/100] START n_neighbors=23...........................................
# [CV 5/5; 23/100] END n_neighbors=23;, score=(train=0.908, test=0.786) total time=   0.0s
# [CV 1/5; 24/100] START n_neighbors=24...........................................
# [CV 1/5; 24/100] END n_neighbors=24;, score=(train=0.896, test=0.887) total time=   0.0s
# [CV 2/5; 24/100] START n_neighbors=24...........................................
# [CV 2/5; 24/100] END n_neighbors=24;, score=(train=0.888, test=0.928) total time=   0.0s
# [CV 3/5; 24/100] START n_neighbors=24...........................................
# [CV 3/5; 24/100] END n_neighbors=24;, score=(train=0.899, test=0.868) total time=   0.0s
# [CV 4/5; 24/100] START n_neighbors=24...........................................
# [CV 4/5; 24/100] END n_neighbors=24;, score=(train=0.887, test=0.933) total time=   0.0s
# [CV 5/5; 24/100] START n_neighbors=24...........................................
# [CV 5/5; 24/100] END n_neighbors=24;, score=(train=0.910, test=0.787) total time=   0.0s
# [CV 1/5; 25/100] START n_neighbors=25...........................................
# [CV 1/5; 25/100] END n_neighbors=25;, score=(train=0.904, test=0.894) total time=   0.0s
# [CV 2/5; 25/100] START n_neighbors=25...........................................
# [CV 2/5; 25/100] END n_neighbors=25;, score=(train=0.889, test=0.930) total time=   0.0s
# [CV 3/5; 25/100] START n_neighbors=25...........................................
# [CV 3/5; 25/100] END n_neighbors=25;, score=(train=0.894, test=0.874) total time=   0.0s
# [CV 4/5; 25/100] START n_neighbors=25...........................................
# [CV 4/5; 25/100] END n_neighbors=25;, score=(train=0.887, test=0.931) total time=   0.0s
# [CV 5/5; 25/100] START n_neighbors=25...........................................
# [CV 5/5; 25/100] END n_neighbors=25;, score=(train=0.911, test=0.784) total time=   0.0s
# [CV 1/5; 26/100] START n_neighbors=26...........................................
# [CV 1/5; 26/100] END n_neighbors=26;, score=(train=0.901, test=0.900) total time=   0.0s
# [CV 2/5; 26/100] START n_neighbors=26...........................................
# [CV 2/5; 26/100] END n_neighbors=26;, score=(train=0.895, test=0.930) total time=   0.0s
# [CV 3/5; 26/100] START n_neighbors=26...........................................
# [CV 3/5; 26/100] END n_neighbors=26;, score=(train=0.891, test=0.869) total time=   0.0s
# [CV 4/5; 26/100] START n_neighbors=26...........................................
# [CV 4/5; 26/100] END n_neighbors=26;, score=(train=0.888, test=0.935) total time=   0.0s
# [CV 5/5; 26/100] START n_neighbors=26...........................................
# [CV 5/5; 26/100] END n_neighbors=26;, score=(train=0.911, test=0.796) total time=   0.0s
# [CV 1/5; 27/100] START n_neighbors=27...........................................
# [CV 1/5; 27/100] END n_neighbors=27;, score=(train=0.905, test=0.899) total time=   0.0s
# [CV 2/5; 27/100] START n_neighbors=27...........................................
# [CV 2/5; 27/100] END n_neighbors=27;, score=(train=0.889, test=0.933) total time=   0.0s
# [CV 3/5; 27/100] START n_neighbors=27...........................................
# [CV 3/5; 27/100] END n_neighbors=27;, score=(train=0.890, test=0.865) total time=   0.0s
# [CV 4/5; 27/100] START n_neighbors=27...........................................
# [CV 4/5; 27/100] END n_neighbors=27;, score=(train=0.889, test=0.937) total time=   0.0s
# [CV 5/5; 27/100] START n_neighbors=27...........................................
# [CV 5/5; 27/100] END n_neighbors=27;, score=(train=0.907, test=0.796) total time=   0.0s
# [CV 1/5; 28/100] START n_neighbors=28...........................................
# [CV 1/5; 28/100] END n_neighbors=28;, score=(train=0.902, test=0.900) total time=   0.0s
# [CV 2/5; 28/100] START n_neighbors=28...........................................
# [CV 2/5; 28/100] END n_neighbors=28;, score=(train=0.888, test=0.931) total time=   0.0s
# [CV 3/5; 28/100] START n_neighbors=28...........................................
# [CV 3/5; 28/100] END n_neighbors=28;, score=(train=0.900, test=0.870) total time=   0.0s
# [CV 4/5; 28/100] START n_neighbors=28...........................................
# [CV 4/5; 28/100] END n_neighbors=28;, score=(train=0.886, test=0.936) total time=   0.0s
# [CV 5/5; 28/100] START n_neighbors=28...........................................
# [CV 5/5; 28/100] END n_neighbors=28;, score=(train=0.908, test=0.784) total time=   0.0s
# [CV 1/5; 29/100] START n_neighbors=29...........................................
# [CV 1/5; 29/100] END n_neighbors=29;, score=(train=0.905, test=0.903) total time=   0.0s
# [CV 2/5; 29/100] START n_neighbors=29...........................................
# [CV 2/5; 29/100] END n_neighbors=29;, score=(train=0.886, test=0.931) total time=   0.0s
# [CV 3/5; 29/100] START n_neighbors=29...........................................
# [CV 3/5; 29/100] END n_neighbors=29;, score=(train=0.902, test=0.869) total time=   0.0s
# [CV 4/5; 29/100] START n_neighbors=29...........................................
# [CV 4/5; 29/100] END n_neighbors=29;, score=(train=0.883, test=0.932) total time=   0.0s
# [CV 5/5; 29/100] START n_neighbors=29...........................................
# [CV 5/5; 29/100] END n_neighbors=29;, score=(train=0.906, test=0.793) total time=   0.0s
# [CV 1/5; 30/100] START n_neighbors=30...........................................
# [CV 1/5; 30/100] END n_neighbors=30;, score=(train=0.901, test=0.905) total time=   0.0s
# [CV 2/5; 30/100] START n_neighbors=30...........................................
# [CV 2/5; 30/100] END n_neighbors=30;, score=(train=0.887, test=0.928) total time=   0.0s
# [CV 3/5; 30/100] START n_neighbors=30...........................................
# [CV 3/5; 30/100] END n_neighbors=30;, score=(train=0.902, test=0.862) total time=   0.0s
# [CV 4/5; 30/100] START n_neighbors=30...........................................
# [CV 4/5; 30/100] END n_neighbors=30;, score=(train=0.885, test=0.934) total time=   0.0s
# [CV 5/5; 30/100] START n_neighbors=30...........................................
# [CV 5/5; 30/100] END n_neighbors=30;, score=(train=0.910, test=0.789) total time=   0.0s
# [CV 1/5; 31/100] START n_neighbors=31...........................................
# [CV 1/5; 31/100] END n_neighbors=31;, score=(train=0.905, test=0.905) total time=   0.0s
# [CV 2/5; 31/100] START n_neighbors=31...........................................
# [CV 2/5; 31/100] END n_neighbors=31;, score=(train=0.885, test=0.928) total time=   0.0s
# [CV 3/5; 31/100] START n_neighbors=31...........................................
# [CV 3/5; 31/100] END n_neighbors=31;, score=(train=0.901, test=0.867) total time=   0.0s
# [CV 4/5; 31/100] START n_neighbors=31...........................................
# [CV 4/5; 31/100] END n_neighbors=31;, score=(train=0.884, test=0.935) total time=   0.0s
# [CV 5/5; 31/100] START n_neighbors=31...........................................
# [CV 5/5; 31/100] END n_neighbors=31;, score=(train=0.910, test=0.800) total time=   0.0s
# [CV 1/5; 32/100] START n_neighbors=32...........................................
# [CV 1/5; 32/100] END n_neighbors=32;, score=(train=0.902, test=0.901) total time=   0.0s
# [CV 2/5; 32/100] START n_neighbors=32...........................................
# [CV 2/5; 32/100] END n_neighbors=32;, score=(train=0.883, test=0.929) total time=   0.0s
# [CV 3/5; 32/100] START n_neighbors=32...........................................
# [CV 3/5; 32/100] END n_neighbors=32;, score=(train=0.900, test=0.870) total time=   0.0s
# [CV 4/5; 32/100] START n_neighbors=32...........................................
# [CV 4/5; 32/100] END n_neighbors=32;, score=(train=0.887, test=0.943) total time=   0.0s
# [CV 5/5; 32/100] START n_neighbors=32...........................................
# [CV 5/5; 32/100] END n_neighbors=32;, score=(train=0.911, test=0.797) total time=   0.0s
# [CV 1/5; 33/100] START n_neighbors=33...........................................
# [CV 1/5; 33/100] END n_neighbors=33;, score=(train=0.899, test=0.899) total time=   0.0s
# [CV 2/5; 33/100] START n_neighbors=33...........................................
# [CV 2/5; 33/100] END n_neighbors=33;, score=(train=0.885, test=0.931) total time=   0.0s
# [CV 3/5; 33/100] START n_neighbors=33...........................................
# [CV 3/5; 33/100] END n_neighbors=33;, score=(train=0.902, test=0.872) total time=   0.0s
# [CV 4/5; 33/100] START n_neighbors=33...........................................
# [CV 4/5; 33/100] END n_neighbors=33;, score=(train=0.884, test=0.938) total time=   0.0s
# [CV 5/5; 33/100] START n_neighbors=33...........................................
# [CV 5/5; 33/100] END n_neighbors=33;, score=(train=0.909, test=0.789) total time=   0.0s
# [CV 1/5; 34/100] START n_neighbors=34...........................................
# [CV 1/5; 34/100] END n_neighbors=34;, score=(train=0.899, test=0.897) total time=   0.0s
# [CV 2/5; 34/100] START n_neighbors=34...........................................
# [CV 2/5; 34/100] END n_neighbors=34;, score=(train=0.883, test=0.934) total time=   0.0s
# [CV 3/5; 34/100] START n_neighbors=34...........................................
# [CV 3/5; 34/100] END n_neighbors=34;, score=(train=0.899, test=0.879) total time=   0.0s
# [CV 4/5; 34/100] START n_neighbors=34...........................................
# [CV 4/5; 34/100] END n_neighbors=34;, score=(train=0.888, test=0.936) total time=   0.0s
# [CV 5/5; 34/100] START n_neighbors=34...........................................
# [CV 5/5; 34/100] END n_neighbors=34;, score=(train=0.912, test=0.788) total time=   0.0s
# [CV 1/5; 35/100] START n_neighbors=35...........................................
# [CV 1/5; 35/100] END n_neighbors=35;, score=(train=0.900, test=0.904) total time=   0.0s
# [CV 2/5; 35/100] START n_neighbors=35...........................................
# [CV 2/5; 35/100] END n_neighbors=35;, score=(train=0.882, test=0.938) total time=   0.0s
# [CV 3/5; 35/100] START n_neighbors=35...........................................
# [CV 3/5; 35/100] END n_neighbors=35;, score=(train=0.900, test=0.886) total time=   0.0s
# [CV 4/5; 35/100] START n_neighbors=35...........................................
# [CV 4/5; 35/100] END n_neighbors=35;, score=(train=0.891, test=0.936) total time=   0.0s
# [CV 5/5; 35/100] START n_neighbors=35...........................................
# [CV 5/5; 35/100] END n_neighbors=35;, score=(train=0.913, test=0.778) total time=   0.0s
# [CV 1/5; 36/100] START n_neighbors=36...........................................
# [CV 1/5; 36/100] END n_neighbors=36;, score=(train=0.900, test=0.896) total time=   0.0s
# [CV 2/5; 36/100] START n_neighbors=36...........................................
# [CV 2/5; 36/100] END n_neighbors=36;, score=(train=0.884, test=0.932) total time=   0.0s
# [CV 3/5; 36/100] START n_neighbors=36...........................................
# [CV 3/5; 36/100] END n_neighbors=36;, score=(train=0.902, test=0.883) total time=   0.0s
# [CV 4/5; 36/100] START n_neighbors=36...........................................
# [CV 4/5; 36/100] END n_neighbors=36;, score=(train=0.889, test=0.945) total time=   0.0s
# [CV 5/5; 36/100] START n_neighbors=36...........................................
# [CV 5/5; 36/100] END n_neighbors=36;, score=(train=0.914, test=0.796) total time=   0.0s
# [CV 1/5; 37/100] START n_neighbors=37...........................................
# [CV 1/5; 37/100] END n_neighbors=37;, score=(train=0.899, test=0.899) total time=   0.0s
# [CV 2/5; 37/100] START n_neighbors=37...........................................
# [CV 2/5; 37/100] END n_neighbors=37;, score=(train=0.886, test=0.937) total time=   0.0s
# [CV 3/5; 37/100] START n_neighbors=37...........................................
# [CV 3/5; 37/100] END n_neighbors=37;, score=(train=0.901, test=0.875) total time=   0.0s
# [CV 4/5; 37/100] START n_neighbors=37...........................................
# [CV 4/5; 37/100] END n_neighbors=37;, score=(train=0.891, test=0.947) total time=   0.0s
# [CV 5/5; 37/100] START n_neighbors=37...........................................
# [CV 5/5; 37/100] END n_neighbors=37;, score=(train=0.917, test=0.797) total time=   0.0s
# [CV 1/5; 38/100] START n_neighbors=38...........................................
# [CV 1/5; 38/100] END n_neighbors=38;, score=(train=0.896, test=0.908) total time=   0.0s
# [CV 2/5; 38/100] START n_neighbors=38...........................................
# [CV 2/5; 38/100] END n_neighbors=38;, score=(train=0.887, test=0.938) total time=   0.0s
# [CV 3/5; 38/100] START n_neighbors=38...........................................
# [CV 3/5; 38/100] END n_neighbors=38;, score=(train=0.901, test=0.880) total time=   0.0s
# [CV 4/5; 38/100] START n_neighbors=38...........................................
# [CV 4/5; 38/100] END n_neighbors=38;, score=(train=0.889, test=0.948) total time=   0.0s
# [CV 5/5; 38/100] START n_neighbors=38...........................................
# [CV 5/5; 38/100] END n_neighbors=38;, score=(train=0.914, test=0.794) total time=   0.0s
# [CV 1/5; 39/100] START n_neighbors=39...........................................
# [CV 1/5; 39/100] END n_neighbors=39;, score=(train=0.896, test=0.906) total time=   0.0s
# [CV 2/5; 39/100] START n_neighbors=39...........................................
# [CV 2/5; 39/100] END n_neighbors=39;, score=(train=0.884, test=0.940) total time=   0.0s
# [CV 3/5; 39/100] START n_neighbors=39...........................................
# [CV 3/5; 39/100] END n_neighbors=39;, score=(train=0.902, test=0.884) total time=   0.0s
# [CV 4/5; 39/100] START n_neighbors=39...........................................
# [CV 4/5; 39/100] END n_neighbors=39;, score=(train=0.888, test=0.946) total time=   0.0s
# [CV 5/5; 39/100] START n_neighbors=39...........................................
# [CV 5/5; 39/100] END n_neighbors=39;, score=(train=0.913, test=0.798) total time=   0.0s
# [CV 1/5; 40/100] START n_neighbors=40...........................................
# [CV 1/5; 40/100] END n_neighbors=40;, score=(train=0.896, test=0.901) total time=   0.0s
# [CV 2/5; 40/100] START n_neighbors=40...........................................
# [CV 2/5; 40/100] END n_neighbors=40;, score=(train=0.881, test=0.939) total time=   0.0s
# [CV 3/5; 40/100] START n_neighbors=40...........................................
# [CV 3/5; 40/100] END n_neighbors=40;, score=(train=0.900, test=0.887) total time=   0.0s
# [CV 4/5; 40/100] START n_neighbors=40...........................................
# [CV 4/5; 40/100] END n_neighbors=40;, score=(train=0.891, test=0.945) total time=   0.0s
# [CV 5/5; 40/100] START n_neighbors=40...........................................
# [CV 5/5; 40/100] END n_neighbors=40;, score=(train=0.911, test=0.789) total time=   0.0s
# [CV 1/5; 41/100] START n_neighbors=41...........................................
# [CV 1/5; 41/100] END n_neighbors=41;, score=(train=0.893, test=0.897) total time=   0.0s
# [CV 2/5; 41/100] START n_neighbors=41...........................................
# [CV 2/5; 41/100] END n_neighbors=41;, score=(train=0.882, test=0.939) total time=   0.0s
# [CV 3/5; 41/100] START n_neighbors=41...........................................
# [CV 3/5; 41/100] END n_neighbors=41;, score=(train=0.899, test=0.882) total time=   0.0s
# [CV 4/5; 41/100] START n_neighbors=41...........................................
# [CV 4/5; 41/100] END n_neighbors=41;, score=(train=0.888, test=0.940) total time=   0.0s
# [CV 5/5; 41/100] START n_neighbors=41...........................................
# [CV 5/5; 41/100] END n_neighbors=41;, score=(train=0.908, test=0.803) total time=   0.0s
# [CV 1/5; 42/100] START n_neighbors=42...........................................
# [CV 1/5; 42/100] END n_neighbors=42;, score=(train=0.893, test=0.899) total time=   0.0s
# [CV 2/5; 42/100] START n_neighbors=42...........................................
# [CV 2/5; 42/100] END n_neighbors=42;, score=(train=0.883, test=0.941) total time=   0.0s
# [CV 3/5; 42/100] START n_neighbors=42...........................................
# [CV 3/5; 42/100] END n_neighbors=42;, score=(train=0.899, test=0.884) total time=   0.0s
# [CV 4/5; 42/100] START n_neighbors=42...........................................
# [CV 4/5; 42/100] END n_neighbors=42;, score=(train=0.892, test=0.943) total time=   0.0s
# [CV 5/5; 42/100] START n_neighbors=42...........................................
# [CV 5/5; 42/100] END n_neighbors=42;, score=(train=0.908, test=0.807) total time=   0.0s
# [CV 1/5; 43/100] START n_neighbors=43...........................................
# [CV 1/5; 43/100] END n_neighbors=43;, score=(train=0.894, test=0.900) total time=   0.0s
# [CV 2/5; 43/100] START n_neighbors=43...........................................
# [CV 2/5; 43/100] END n_neighbors=43;, score=(train=0.885, test=0.939) total time=   0.0s
# [CV 3/5; 43/100] START n_neighbors=43...........................................
# [CV 3/5; 43/100] END n_neighbors=43;, score=(train=0.893, test=0.889) total time=   0.0s
# [CV 4/5; 43/100] START n_neighbors=43...........................................
# [CV 4/5; 43/100] END n_neighbors=43;, score=(train=0.891, test=0.945) total time=   0.0s
# [CV 5/5; 43/100] START n_neighbors=43...........................................
# [CV 5/5; 43/100] END n_neighbors=43;, score=(train=0.909, test=0.795) total time=   0.0s
# [CV 1/5; 44/100] START n_neighbors=44...........................................
# [CV 1/5; 44/100] END n_neighbors=44;, score=(train=0.893, test=0.903) total time=   0.0s
# [CV 2/5; 44/100] START n_neighbors=44...........................................
# [CV 2/5; 44/100] END n_neighbors=44;, score=(train=0.886, test=0.942) total time=   0.0s
# [CV 3/5; 44/100] START n_neighbors=44...........................................
# [CV 3/5; 44/100] END n_neighbors=44;, score=(train=0.892, test=0.885) total time=   0.0s
# [CV 4/5; 44/100] START n_neighbors=44...........................................
# [CV 4/5; 44/100] END n_neighbors=44;, score=(train=0.890, test=0.938) total time=   0.0s
# [CV 5/5; 44/100] START n_neighbors=44...........................................
# [CV 5/5; 44/100] END n_neighbors=44;, score=(train=0.908, test=0.809) total time=   0.0s
# [CV 1/5; 45/100] START n_neighbors=45...........................................
# [CV 1/5; 45/100] END n_neighbors=45;, score=(train=0.892, test=0.901) total time=   0.0s
# [CV 2/5; 45/100] START n_neighbors=45...........................................
# [CV 2/5; 45/100] END n_neighbors=45;, score=(train=0.886, test=0.939) total time=   0.0s
# [CV 3/5; 45/100] START n_neighbors=45...........................................
# [CV 3/5; 45/100] END n_neighbors=45;, score=(train=0.895, test=0.888) total time=   0.0s
# [CV 4/5; 45/100] START n_neighbors=45...........................................
# [CV 4/5; 45/100] END n_neighbors=45;, score=(train=0.888, test=0.940) total time=   0.0s
# [CV 5/5; 45/100] START n_neighbors=45...........................................
# [CV 5/5; 45/100] END n_neighbors=45;, score=(train=0.909, test=0.809) total time=   0.0s
# [CV 1/5; 46/100] START n_neighbors=46...........................................
# [CV 1/5; 46/100] END n_neighbors=46;, score=(train=0.892, test=0.900) total time=   0.0s
# [CV 2/5; 46/100] START n_neighbors=46...........................................
# [CV 2/5; 46/100] END n_neighbors=46;, score=(train=0.884, test=0.935) total time=   0.0s
# [CV 3/5; 46/100] START n_neighbors=46...........................................
# [CV 3/5; 46/100] END n_neighbors=46;, score=(train=0.894, test=0.888) total time=   0.0s
# [CV 4/5; 46/100] START n_neighbors=46...........................................
# [CV 4/5; 46/100] END n_neighbors=46;, score=(train=0.893, test=0.935) total time=   0.0s
# [CV 5/5; 46/100] START n_neighbors=46...........................................
# [CV 5/5; 46/100] END n_neighbors=46;, score=(train=0.912, test=0.797) total time=   0.0s
# [CV 1/5; 47/100] START n_neighbors=47...........................................
# [CV 1/5; 47/100] END n_neighbors=47;, score=(train=0.890, test=0.897) total time=   0.0s
# [CV 2/5; 47/100] START n_neighbors=47...........................................
# [CV 2/5; 47/100] END n_neighbors=47;, score=(train=0.885, test=0.936) total time=   0.0s
# [CV 3/5; 47/100] START n_neighbors=47...........................................
# [CV 3/5; 47/100] END n_neighbors=47;, score=(train=0.896, test=0.887) total time=   0.0s
# [CV 4/5; 47/100] START n_neighbors=47...........................................
# [CV 4/5; 47/100] END n_neighbors=47;, score=(train=0.890, test=0.936) total time=   0.0s
# [CV 5/5; 47/100] START n_neighbors=47...........................................
# [CV 5/5; 47/100] END n_neighbors=47;, score=(train=0.911, test=0.799) total time=   0.0s
# [CV 1/5; 48/100] START n_neighbors=48...........................................
# [CV 1/5; 48/100] END n_neighbors=48;, score=(train=0.889, test=0.898) total time=   0.0s
# [CV 2/5; 48/100] START n_neighbors=48...........................................
# [CV 2/5; 48/100] END n_neighbors=48;, score=(train=0.884, test=0.938) total time=   0.0s
# [CV 3/5; 48/100] START n_neighbors=48...........................................
# [CV 3/5; 48/100] END n_neighbors=48;, score=(train=0.895, test=0.887) total time=   0.0s
# [CV 4/5; 48/100] START n_neighbors=48...........................................
# [CV 4/5; 48/100] END n_neighbors=48;, score=(train=0.893, test=0.936) total time=   0.0s
# [CV 5/5; 48/100] START n_neighbors=48...........................................
# [CV 5/5; 48/100] END n_neighbors=48;, score=(train=0.912, test=0.789) total time=   0.0s
# [CV 1/5; 49/100] START n_neighbors=49...........................................
# [CV 1/5; 49/100] END n_neighbors=49;, score=(train=0.892, test=0.893) total time=   0.0s
# [CV 2/5; 49/100] START n_neighbors=49...........................................
# [CV 2/5; 49/100] END n_neighbors=49;, score=(train=0.884, test=0.933) total time=   0.0s
# [CV 3/5; 49/100] START n_neighbors=49...........................................
# [CV 3/5; 49/100] END n_neighbors=49;, score=(train=0.893, test=0.888) total time=   0.0s
# [CV 4/5; 49/100] START n_neighbors=49...........................................
# [CV 4/5; 49/100] END n_neighbors=49;, score=(train=0.891, test=0.944) total time=   0.0s
# [CV 5/5; 49/100] START n_neighbors=49...........................................
# [CV 5/5; 49/100] END n_neighbors=49;, score=(train=0.912, test=0.785) total time=   0.0s
# [CV 1/5; 50/100] START n_neighbors=50...........................................
# [CV 1/5; 50/100] END n_neighbors=50;, score=(train=0.891, test=0.895) total time=   0.0s
# [CV 2/5; 50/100] START n_neighbors=50...........................................
# [CV 2/5; 50/100] END n_neighbors=50;, score=(train=0.883, test=0.938) total time=   0.0s
# [CV 3/5; 50/100] START n_neighbors=50...........................................
# [CV 3/5; 50/100] END n_neighbors=50;, score=(train=0.898, test=0.889) total time=   0.0s
# [CV 4/5; 50/100] START n_neighbors=50...........................................
# [CV 4/5; 50/100] END n_neighbors=50;, score=(train=0.891, test=0.947) total time=   0.0s
# [CV 5/5; 50/100] START n_neighbors=50...........................................
# [CV 5/5; 50/100] END n_neighbors=50;, score=(train=0.910, test=0.786) total time=   0.0s
# [CV 1/5; 51/100] START n_neighbors=51...........................................
# [CV 1/5; 51/100] END n_neighbors=51;, score=(train=0.890, test=0.900) total time=   0.0s
# [CV 2/5; 51/100] START n_neighbors=51...........................................
# [CV 2/5; 51/100] END n_neighbors=51;, score=(train=0.883, test=0.938) total time=   0.0s
# [CV 3/5; 51/100] START n_neighbors=51...........................................
# [CV 3/5; 51/100] END n_neighbors=51;, score=(train=0.895, test=0.893) total time=   0.0s
# [CV 4/5; 51/100] START n_neighbors=51...........................................
# [CV 4/5; 51/100] END n_neighbors=51;, score=(train=0.888, test=0.944) total time=   0.0s
# [CV 5/5; 51/100] START n_neighbors=51...........................................
# [CV 5/5; 51/100] END n_neighbors=51;, score=(train=0.909, test=0.789) total time=   0.0s
# [CV 1/5; 52/100] START n_neighbors=52...........................................
# [CV 1/5; 52/100] END n_neighbors=52;, score=(train=0.890, test=0.900) total time=   0.0s
# [CV 2/5; 52/100] START n_neighbors=52...........................................
# [CV 2/5; 52/100] END n_neighbors=52;, score=(train=0.883, test=0.934) total time=   0.0s
# [CV 3/5; 52/100] START n_neighbors=52...........................................
# [CV 3/5; 52/100] END n_neighbors=52;, score=(train=0.894, test=0.897) total time=   0.0s
# [CV 4/5; 52/100] START n_neighbors=52...........................................
# [CV 4/5; 52/100] END n_neighbors=52;, score=(train=0.887, test=0.947) total time=   0.0s
# [CV 5/5; 52/100] START n_neighbors=52...........................................
# [CV 5/5; 52/100] END n_neighbors=52;, score=(train=0.909, test=0.800) total time=   0.0s
# [CV 1/5; 53/100] START n_neighbors=53...........................................
# [CV 1/5; 53/100] END n_neighbors=53;, score=(train=0.895, test=0.897) total time=   0.0s
# [CV 2/5; 53/100] START n_neighbors=53...........................................
# [CV 2/5; 53/100] END n_neighbors=53;, score=(train=0.881, test=0.944) total time=   0.0s
# [CV 3/5; 53/100] START n_neighbors=53...........................................
# [CV 3/5; 53/100] END n_neighbors=53;, score=(train=0.898, test=0.894) total time=   0.0s
# [CV 4/5; 53/100] START n_neighbors=53...........................................
# [CV 4/5; 53/100] END n_neighbors=53;, score=(train=0.889, test=0.944) total time=   0.0s
# [CV 5/5; 53/100] START n_neighbors=53...........................................
# [CV 5/5; 53/100] END n_neighbors=53;, score=(train=0.910, test=0.794) total time=   0.0s
# [CV 1/5; 54/100] START n_neighbors=54...........................................
# [CV 1/5; 54/100] END n_neighbors=54;, score=(train=0.895, test=0.897) total time=   0.0s
# [CV 2/5; 54/100] START n_neighbors=54...........................................
# [CV 2/5; 54/100] END n_neighbors=54;, score=(train=0.880, test=0.943) total time=   0.0s
# [CV 3/5; 54/100] START n_neighbors=54...........................................
# [CV 3/5; 54/100] END n_neighbors=54;, score=(train=0.895, test=0.896) total time=   0.0s
# [CV 4/5; 54/100] START n_neighbors=54...........................................
# [CV 4/5; 54/100] END n_neighbors=54;, score=(train=0.886, test=0.942) total time=   0.0s
# [CV 5/5; 54/100] START n_neighbors=54...........................................
# [CV 5/5; 54/100] END n_neighbors=54;, score=(train=0.911, test=0.798) total time=   0.0s
# [CV 1/5; 55/100] START n_neighbors=55...........................................
# [CV 1/5; 55/100] END n_neighbors=55;, score=(train=0.895, test=0.903) total time=   0.0s
# [CV 2/5; 55/100] START n_neighbors=55...........................................
# [CV 2/5; 55/100] END n_neighbors=55;, score=(train=0.878, test=0.938) total time=   0.0s
# [CV 3/5; 55/100] START n_neighbors=55...........................................
# [CV 3/5; 55/100] END n_neighbors=55;, score=(train=0.896, test=0.892) total time=   0.0s
# [CV 4/5; 55/100] START n_neighbors=55...........................................
# [CV 4/5; 55/100] END n_neighbors=55;, score=(train=0.887, test=0.942) total time=   0.0s
# [CV 5/5; 55/100] START n_neighbors=55...........................................
# [CV 5/5; 55/100] END n_neighbors=55;, score=(train=0.913, test=0.789) total time=   0.0s
# [CV 1/5; 56/100] START n_neighbors=56...........................................
# [CV 1/5; 56/100] END n_neighbors=56;, score=(train=0.896, test=0.914) total time=   0.0s
# [CV 2/5; 56/100] START n_neighbors=56...........................................
# [CV 2/5; 56/100] END n_neighbors=56;, score=(train=0.875, test=0.934) total time=   0.0s
# [CV 3/5; 56/100] START n_neighbors=56...........................................
# [CV 3/5; 56/100] END n_neighbors=56;, score=(train=0.894, test=0.892) total time=   0.0s
# [CV 4/5; 56/100] START n_neighbors=56...........................................
# [CV 4/5; 56/100] END n_neighbors=56;, score=(train=0.889, test=0.937) total time=   0.0s
# [CV 5/5; 56/100] START n_neighbors=56...........................................
# [CV 5/5; 56/100] END n_neighbors=56;, score=(train=0.911, test=0.793) total time=   0.0s
# [CV 1/5; 57/100] START n_neighbors=57...........................................
# [CV 1/5; 57/100] END n_neighbors=57;, score=(train=0.898, test=0.904) total time=   0.0s
# [CV 2/5; 57/100] START n_neighbors=57...........................................
# [CV 2/5; 57/100] END n_neighbors=57;, score=(train=0.873, test=0.935) total time=   0.0s
# [CV 3/5; 57/100] START n_neighbors=57...........................................
# ...
# [CV 3/5; 82/100] END n_neighbors=82;, score=(train=0.886, test=0.883) total time=   0.0s
# [CV 4/5; 82/100] START n_neighbors=82...........................................
# [CV 4/5; 82/100] END n_neighbors=82;, score=(train=0.877, test=0.933) total time=   0.0s
# [CV 5/5; 82/100] START n_neighbors=82...........................................
# [CV 5/5; 82/100] END n_neighbors=82;, score=(train=0.905, test=0.806) total time=   0.0s
# [CV 1/5; 83/100] START n_neighbors=83...........................................
# [CV 1/5; 83/100] END n_neighbors=83;, score=(train=0.883, test=0.908) total time=   0.0s
# [CV 2/5; 83/100] START n_neighbors=83...........................................
# [CV 2/5; 83/100] END n_neighbors=83;, score=(train=0.877, test=0.931) total time=   0.0s
# [CV 3/5; 83/100] START n_neighbors=83...........................................
# [CV 3/5; 83/100] END n_neighbors=83;, score=(train=0.885, test=0.881) total time=   0.0s
# [CV 4/5; 83/100] START n_neighbors=83...........................................
# [CV 4/5; 83/100] END n_neighbors=83;, score=(train=0.878, test=0.937) total time=   0.0s
# [CV 5/5; 83/100] START n_neighbors=83...........................................
# [CV 5/5; 83/100] END n_neighbors=83;, score=(train=0.902, test=0.806) total time=   0.0s
# [CV 1/5; 84/100] START n_neighbors=84...........................................
# [CV 1/5; 84/100] END n_neighbors=84;, score=(train=0.884, test=0.911) total time=   0.0s
# [CV 2/5; 84/100] START n_neighbors=84...........................................
# [CV 2/5; 84/100] END n_neighbors=84;, score=(train=0.879, test=0.929) total time=   0.0s
# [CV 3/5; 84/100] START n_neighbors=84...........................................
# [CV 3/5; 84/100] END n_neighbors=84;, score=(train=0.885, test=0.883) total time=   0.0s
# [CV 4/5; 84/100] START n_neighbors=84...........................................
# [CV 4/5; 84/100] END n_neighbors=84;, score=(train=0.878, test=0.932) total time=   0.0s
# [CV 5/5; 84/100] START n_neighbors=84...........................................
# [CV 5/5; 84/100] END n_neighbors=84;, score=(train=0.903, test=0.802) total time=   0.0s
# [CV 1/5; 85/100] START n_neighbors=85...........................................
# [CV 1/5; 85/100] END n_neighbors=85;, score=(train=0.885, test=0.909) total time=   0.0s
# [CV 2/5; 85/100] START n_neighbors=85...........................................
# [CV 2/5; 85/100] END n_neighbors=85;, score=(train=0.876, test=0.927) total time=   0.0s
# [CV 3/5; 85/100] START n_neighbors=85...........................................
# [CV 3/5; 85/100] END n_neighbors=85;, score=(train=0.882, test=0.886) total time=   0.0s
# [CV 4/5; 85/100] START n_neighbors=85...........................................
# [CV 4/5; 85/100] END n_neighbors=85;, score=(train=0.877, test=0.933) total time=   0.0s
# [CV 5/5; 85/100] START n_neighbors=85...........................................
# [CV 5/5; 85/100] END n_neighbors=85;, score=(train=0.902, test=0.798) total time=   0.0s
# [CV 1/5; 86/100] START n_neighbors=86...........................................
# [CV 1/5; 86/100] END n_neighbors=86;, score=(train=0.884, test=0.909) total time=   0.0s
# [CV 2/5; 86/100] START n_neighbors=86...........................................
# [CV 2/5; 86/100] END n_neighbors=86;, score=(train=0.875, test=0.923) total time=   0.0s
# [CV 3/5; 86/100] START n_neighbors=86...........................................
# [CV 3/5; 86/100] END n_neighbors=86;, score=(train=0.882, test=0.885) total time=   0.0s
# [CV 4/5; 86/100] START n_neighbors=86...........................................
# [CV 4/5; 86/100] END n_neighbors=86;, score=(train=0.879, test=0.931) total time=   0.0s
# [CV 5/5; 86/100] START n_neighbors=86...........................................
# [CV 5/5; 86/100] END n_neighbors=86;, score=(train=0.904, test=0.805) total time=   0.0s
# [CV 1/5; 87/100] START n_neighbors=87...........................................
# [CV 1/5; 87/100] END n_neighbors=87;, score=(train=0.885, test=0.906) total time=   0.0s
# [CV 2/5; 87/100] START n_neighbors=87...........................................
# [CV 2/5; 87/100] END n_neighbors=87;, score=(train=0.875, test=0.926) total time=   0.0s
# [CV 3/5; 87/100] START n_neighbors=87...........................................
# [CV 3/5; 87/100] END n_neighbors=87;, score=(train=0.882, test=0.889) total time=   0.0s
# [CV 4/5; 87/100] START n_neighbors=87...........................................
# [CV 4/5; 87/100] END n_neighbors=87;, score=(train=0.881, test=0.930) total time=   0.0s
# [CV 5/5; 87/100] START n_neighbors=87...........................................
# [CV 5/5; 87/100] END n_neighbors=87;, score=(train=0.903, test=0.792) total time=   0.0s
# [CV 1/5; 88/100] START n_neighbors=88...........................................
# [CV 1/5; 88/100] END n_neighbors=88;, score=(train=0.884, test=0.910) total time=   0.0s
# [CV 2/5; 88/100] START n_neighbors=88...........................................
# [CV 2/5; 88/100] END n_neighbors=88;, score=(train=0.875, test=0.927) total time=   0.0s
# [CV 3/5; 88/100] START n_neighbors=88...........................................
# [CV 3/5; 88/100] END n_neighbors=88;, score=(train=0.884, test=0.886) total time=   0.0s
# [CV 4/5; 88/100] START n_neighbors=88...........................................
# [CV 4/5; 88/100] END n_neighbors=88;, score=(train=0.880, test=0.936) total time=   0.0s
# [CV 5/5; 88/100] START n_neighbors=88...........................................
# [CV 5/5; 88/100] END n_neighbors=88;, score=(train=0.902, test=0.786) total time=   0.0s
# [CV 1/5; 89/100] START n_neighbors=89...........................................
# [CV 1/5; 89/100] END n_neighbors=89;, score=(train=0.882, test=0.903) total time=   0.0s
# [CV 2/5; 89/100] START n_neighbors=89...........................................
# [CV 2/5; 89/100] END n_neighbors=89;, score=(train=0.878, test=0.925) total time=   0.0s
# [CV 3/5; 89/100] START n_neighbors=89...........................................
# [CV 3/5; 89/100] END n_neighbors=89;, score=(train=0.884, test=0.888) total time=   0.0s
# [CV 4/5; 89/100] START n_neighbors=89...........................................
# [CV 4/5; 89/100] END n_neighbors=89;, score=(train=0.879, test=0.933) total time=   0.0s
# [CV 5/5; 89/100] START n_neighbors=89...........................................
# [CV 5/5; 89/100] END n_neighbors=89;, score=(train=0.902, test=0.788) total time=   0.0s
# [CV 1/5; 90/100] START n_neighbors=90...........................................
# [CV 1/5; 90/100] END n_neighbors=90;, score=(train=0.881, test=0.899) total time=   0.0s
# [CV 2/5; 90/100] START n_neighbors=90...........................................
# [CV 2/5; 90/100] END n_neighbors=90;, score=(train=0.875, test=0.928) total time=   0.0s
# [CV 3/5; 90/100] START n_neighbors=90...........................................
# [CV 3/5; 90/100] END n_neighbors=90;, score=(train=0.885, test=0.890) total time=   0.0s
# [CV 4/5; 90/100] START n_neighbors=90...........................................
# [CV 4/5; 90/100] END n_neighbors=90;, score=(train=0.880, test=0.933) total time=   0.0s
# [CV 5/5; 90/100] START n_neighbors=90...........................................
# [CV 5/5; 90/100] END n_neighbors=90;, score=(train=0.902, test=0.782) total time=   0.0s
# [CV 1/5; 91/100] START n_neighbors=91...........................................
# [CV 1/5; 91/100] END n_neighbors=91;, score=(train=0.883, test=0.902) total time=   0.0s
# [CV 2/5; 91/100] START n_neighbors=91...........................................
# [CV 2/5; 91/100] END n_neighbors=91;, score=(train=0.873, test=0.927) total time=   0.0s
# [CV 3/5; 91/100] START n_neighbors=91...........................................
# [CV 3/5; 91/100] END n_neighbors=91;, score=(train=0.885, test=0.892) total time=   0.0s
# [CV 4/5; 91/100] START n_neighbors=91...........................................
# [CV 4/5; 91/100] END n_neighbors=91;, score=(train=0.880, test=0.941) total time=   0.0s
# [CV 5/5; 91/100] START n_neighbors=91...........................................
# [CV 5/5; 91/100] END n_neighbors=91;, score=(train=0.901, test=0.771) total time=   0.0s
# [CV 1/5; 92/100] START n_neighbors=92...........................................
# [CV 1/5; 92/100] END n_neighbors=92;, score=(train=0.879, test=0.901) total time=   0.0s
# [CV 2/5; 92/100] START n_neighbors=92...........................................
# [CV 2/5; 92/100] END n_neighbors=92;, score=(train=0.874, test=0.927) total time=   0.0s
# [CV 3/5; 92/100] START n_neighbors=92...........................................
# [CV 3/5; 92/100] END n_neighbors=92;, score=(train=0.882, test=0.893) total time=   0.0s
# [CV 4/5; 92/100] START n_neighbors=92...........................................
# [CV 4/5; 92/100] END n_neighbors=92;, score=(train=0.880, test=0.938) total time=   0.0s
# [CV 5/5; 92/100] START n_neighbors=92...........................................
# [CV 5/5; 92/100] END n_neighbors=92;, score=(train=0.901, test=0.772) total time=   0.0s
# [CV 1/5; 93/100] START n_neighbors=93...........................................
# [CV 1/5; 93/100] END n_neighbors=93;, score=(train=0.880, test=0.899) total time=   0.0s
# [CV 2/5; 93/100] START n_neighbors=93...........................................
# [CV 2/5; 93/100] END n_neighbors=93;, score=(train=0.875, test=0.930) total time=   0.0s
# [CV 3/5; 93/100] START n_neighbors=93...........................................
# [CV 3/5; 93/100] END n_neighbors=93;, score=(train=0.881, test=0.893) total time=   0.0s
# [CV 4/5; 93/100] START n_neighbors=93...........................................
# [CV 4/5; 93/100] END n_neighbors=93;, score=(train=0.877, test=0.941) total time=   0.0s
# [CV 5/5; 93/100] START n_neighbors=93...........................................
# [CV 5/5; 93/100] END n_neighbors=93;, score=(train=0.902, test=0.773) total time=   0.0s
# [CV 1/5; 94/100] START n_neighbors=94...........................................
# [CV 1/5; 94/100] END n_neighbors=94;, score=(train=0.879, test=0.903) total time=   0.0s
# [CV 2/5; 94/100] START n_neighbors=94...........................................
# [CV 2/5; 94/100] END n_neighbors=94;, score=(train=0.873, test=0.927) total time=   0.0s
# [CV 3/5; 94/100] START n_neighbors=94...........................................
# [CV 3/5; 94/100] END n_neighbors=94;, score=(train=0.882, test=0.893) total time=   0.0s
# [CV 4/5; 94/100] START n_neighbors=94...........................................
# [CV 4/5; 94/100] END n_neighbors=94;, score=(train=0.876, test=0.940) total time=   0.0s
# [CV 5/5; 94/100] START n_neighbors=94...........................................
# [CV 5/5; 94/100] END n_neighbors=94;, score=(train=0.905, test=0.763) total time=   0.0s
# [CV 1/5; 95/100] START n_neighbors=95...........................................
# [CV 1/5; 95/100] END n_neighbors=95;, score=(train=0.880, test=0.900) total time=   0.0s
# [CV 2/5; 95/100] START n_neighbors=95...........................................
# [CV 2/5; 95/100] END n_neighbors=95;, score=(train=0.875, test=0.927) total time=   0.0s
# [CV 3/5; 95/100] START n_neighbors=95...........................................
# [CV 3/5; 95/100] END n_neighbors=95;, score=(train=0.882, test=0.891) total time=   0.0s
# [CV 4/5; 95/100] START n_neighbors=95...........................................
# [CV 4/5; 95/100] END n_neighbors=95;, score=(train=0.875, test=0.940) total time=   0.0s
# [CV 5/5; 95/100] START n_neighbors=95...........................................
# [CV 5/5; 95/100] END n_neighbors=95;, score=(train=0.906, test=0.769) total time=   0.0s
# [CV 1/5; 96/100] START n_neighbors=96...........................................
# [CV 1/5; 96/100] END n_neighbors=96;, score=(train=0.881, test=0.900) total time=   0.0s
# [CV 2/5; 96/100] START n_neighbors=96...........................................
# [CV 2/5; 96/100] END n_neighbors=96;, score=(train=0.873, test=0.928) total time=   0.0s
# [CV 3/5; 96/100] START n_neighbors=96...........................................
# [CV 3/5; 96/100] END n_neighbors=96;, score=(train=0.883, test=0.893) total time=   0.0s
# [CV 4/5; 96/100] START n_neighbors=96...........................................
# [CV 4/5; 96/100] END n_neighbors=96;, score=(train=0.875, test=0.942) total time=   0.0s
# [CV 5/5; 96/100] START n_neighbors=96...........................................
# [CV 5/5; 96/100] END n_neighbors=96;, score=(train=0.907, test=0.775) total time=   0.0s
# [CV 1/5; 97/100] START n_neighbors=97...........................................
# [CV 1/5; 97/100] END n_neighbors=97;, score=(train=0.884, test=0.899) total time=   0.0s
# [CV 2/5; 97/100] START n_neighbors=97...........................................
# [CV 2/5; 97/100] END n_neighbors=97;, score=(train=0.870, test=0.926) total time=   0.0s
# [CV 3/5; 97/100] START n_neighbors=97...........................................
# [CV 3/5; 97/100] END n_neighbors=97;, score=(train=0.883, test=0.901) total time=   0.0s
# [CV 4/5; 97/100] START n_neighbors=97...........................................
# [CV 4/5; 97/100] END n_neighbors=97;, score=(train=0.872, test=0.942) total time=   0.0s
# [CV 5/5; 97/100] START n_neighbors=97...........................................
# [CV 5/5; 97/100] END n_neighbors=97;, score=(train=0.909, test=0.770) total time=   0.0s
# [CV 1/5; 98/100] START n_neighbors=98...........................................
# [CV 1/5; 98/100] END n_neighbors=98;, score=(train=0.885, test=0.900) total time=   0.0s
# [CV 2/5; 98/100] START n_neighbors=98...........................................
# [CV 2/5; 98/100] END n_neighbors=98;, score=(train=0.873, test=0.925) total time=   0.0s
# [CV 3/5; 98/100] START n_neighbors=98...........................................
# [CV 3/5; 98/100] END n_neighbors=98;, score=(train=0.879, test=0.899) total time=   0.0s
# [CV 4/5; 98/100] START n_neighbors=98...........................................
# [CV 4/5; 98/100] END n_neighbors=98;, score=(train=0.875, test=0.939) total time=   0.0s
# [CV 5/5; 98/100] START n_neighbors=98...........................................
# [CV 5/5; 98/100] END n_neighbors=98;, score=(train=0.911, test=0.758) total time=   0.0s
# [CV 1/5; 99/100] START n_neighbors=99...........................................
# [CV 1/5; 99/100] END n_neighbors=99;, score=(train=0.882, test=0.905) total time=   0.0s
# [CV 2/5; 99/100] START n_neighbors=99...........................................
# [CV 2/5; 99/100] END n_neighbors=99;, score=(train=0.874, test=0.928) total time=   0.0s
# [CV 3/5; 99/100] START n_neighbors=99...........................................
# [CV 3/5; 99/100] END n_neighbors=99;, score=(train=0.881, test=0.902) total time=   0.0s
# [CV 4/5; 99/100] START n_neighbors=99...........................................
# [CV 4/5; 99/100] END n_neighbors=99;, score=(train=0.876, test=0.939) total time=   0.0s
# [CV 5/5; 99/100] START n_neighbors=99...........................................
# [CV 5/5; 99/100] END n_neighbors=99;, score=(train=0.911, test=0.759) total time=   0.0s
# [CV 1/5; 100/100] START n_neighbors=100.........................................
# [CV 1/5; 100/100] END n_neighbors=100;, score=(train=0.882, test=0.892) total time=   0.0s
# [CV 2/5; 100/100] START n_neighbors=100.........................................
# [CV 2/5; 100/100] END n_neighbors=100;, score=(train=0.871, test=0.928) total time=   0.0s
# [CV 3/5; 100/100] START n_neighbors=100.........................................
# [CV 3/5; 100/100] END n_neighbors=100;, score=(train=0.882, test=0.897) total time=   0.0s
# [CV 4/5; 100/100] START n_neighbors=100.........................................
# [CV 4/5; 100/100] END n_neighbors=100;, score=(train=0.876, test=0.948) total time=   0.0s
# [CV 5/5; 100/100] START n_neighbors=100.........................................
# [CV 5/5; 100/100] END n_neighbors=100;, score=(train=0.911, test=0.756) total time=   0.0s
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(1, 101)}, return_train_score=True,
#              scoring='average_precision', verbose=10)

# %%
grid_results = pd.DataFrame(best_model_KNN.cv_results_)
grid_results[['param_n_neighbors',
              'mean_test_score', 
              'mean_train_score', 
              'std_train_score',
              'std_train_score', 
              ]].sort_values(by='mean_test_score', ascending=False)
# Out:
#     param_n_neighbors  mean_test_score  mean_train_score  std_train_score  \
# 51                 52         0.895398          0.892564         0.008918
# 44                 45         0.895391          0.894039         0.008013
# 43                 44         0.895319          0.893903         0.007539
# 53                 54         0.895069          0.893519         0.010577
# 41                 42         0.894629          0.895183         0.008001
# ..                ...              ...               ...              ...
# 7                   8         0.869292          0.918589         0.011200
# 2                   3         0.840359          0.933227         0.011423
# 3                   4         0.838918          0.932431         0.010139
# 1                   2         0.760277          0.927684         0.007947
# 0                   1         0.648040          1.000000         0.000000
#
#     std_train_score
# 51         0.008918
# 44         0.008013
# 43         0.007539
# 53         0.010577
# 41         0.008001
# ..              ...
# 7          0.011200
# 2          0.011423
# 3          0.010139
# 1          0.007947
# 0          0.000000
#
# [100 rows x 5 columns]

# %% [markdown]
# Now let's retrain a model with the optimal value of k obtained on the train set, and find a theshold that gives a recall of 0.95 or higher on the test set. Recompute the precision on the test set and compare it to the one you obtained before grid searching for the optimal value of k.

# %%
best_model_KNN.best_params_
# Out:
# {'n_neighbors': 52}

# %%
knn_clf = KNeighborsClassifier(**best_model_KNN.best_params_)
knn_clf.fit(X_train_scaled, y_train) 

y_train_pred_proba = knn_clf.predict_proba(X_train_scaled)
y_test_pred_proba = knn_clf.predict_proba(X_test_scaled)

threshold = 0.05
y_train_pred_95recall =(y_train_pred_proba[: , 1] > threshold).astype(int)
y_test_pred_95recall = (y_test_pred_proba[:, 1] > threshold).astype(int)

print('TRAIN')
print(f"precision :  {precision_score(y_train, y_train_pred_95recall)}")
print(f"recall : {recall_score(y_train, y_train_pred_95recall)}")

print('--------------------------------------')
print('TEST')
print(f"precision :  {precision_score(y_test, y_test_pred_95recall)}")
print(f"recall : {recall_score(y_test, y_test_pred_95recall)}")
# Out:
# TRAIN
# precision :  0.46190476190476193
# recall : 1.0
# --------------------------------------
# TEST
# precision :  0.45054945054945056
# recall : 1.0

# %% [markdown]
# ## Parity between Men and Women

# %% [markdown]
# Our dataset actually contains more men than women. Men are encoded with 1 in the *sex* column, and women with 0. Compute the men/women ratio :

# %%
plt.figure(figsize=(6,4))
dataset.sex.value_counts().plot.bar(color=['mediumorchid', 'coral'])
plt.ylabel('nombre de patients')
plt.xlabel('Genre')
plt.xticks([0,1], labels=['1=hommes', '0= femmes'], rotation =0)
plt.show()

# %%
plt.figure(figsize=(6,4))
((dataset.sex.value_counts() / dataset.sex.count())*100).plot.bar(color=['mediumorchid', 'coral'])
plt.ylabel('% de patients')
plt.xlabel('Genre')
plt.xticks([0,1], labels=['1=hommes', '0= femmes'], rotation =0)
plt.title('ratio homme femme')
plt.ylim([0,100])
plt.show()

# %% [markdown]
# This could have the effect of having a model biased towards men, that will have a lower precision and recall on women. Medicine has a long-standing history of gender bias. Not only men have been more numerous in clinical studies, but this also had the effect of delaying diagnosis on women, who hence exhibited different symptoms when diagnosed, which could be another source of bias for our model :
#
# https://theconversation.com/gender-bias-in-medicine-and-medical-research-is-still-putting-womens-health-at-risk-156495
#
# To check this, recompute precision and recall (using the last threshold you obtained to get a 0.95 recall), but separately for the men and the women in the test set :

# %%
dataset_genre = pd.concat([X_test_scaled, y_test], axis=1)

X_test_femme = dataset_genre[dataset_genre.sex == 0].drop(columns='target')
y_test_femme= dataset_genre[dataset_genre.sex == 0].target

X_test_homme = dataset_genre[dataset_genre.sex == 1].drop(columns='target')
y_test_homme= dataset_genre[dataset_genre.sex == 1].target

# %%
y_test_proba_femme = knn_clf.predict_proba(X_test_femme)

threshold = 0.174
y_test_pred_femme = (y_test_proba_femme[:, 1] > threshold).astype(int)

print('FEMME')
print(f"precision :  {precision_score(y_test_femme, y_test_pred_femme)}")
print(f"recall : {recall_score(y_test_femme, y_test_pred_femme)}")


y_test_proba_homme = knn_clf.predict_proba(X_test_homme)
y_test_pred_homme = (y_test_proba_homme[:, 1] > threshold).astype(int)

print('------------------------------------')
print('HOMME')
print(f"precision :  {precision_score(y_test_homme, y_test_pred_homme)}")
print(f"recall : {recall_score(y_test_homme, y_test_pred_homme)}")
# Out:
# FEMME
# precision :  0.375
# recall : 0.8571428571428571
# ------------------------------------
# HOMME
# precision :  0.75
# recall : 0.9705882352941176

# %% [markdown]
# Indeed we can see that both recall and precision are much lower on women !
#
# Learn about bias in machine learning models, the different definitions of parity and how to enforce them by reading the following article :
#
# https://www.labelia.org/en/blog/fairness-in-machine-learning
#
# In our case we want to enforce the equality of Opportunity (= same True Positive Rate, = same Recall), since we don't want to miss more women with a heart disease than men.
#
# One way to enforce this is to choose a different threshold that yields a Recall > 0.95 for each group (men and women). Find such thresholds :

# %%
precisions, recalls, thresholds = precision_recall_curve(y_test_femme, y_test_proba_femme[:, 1])
idx_threshold_femme = np.argmax(recalls >= 0.95)
threshold_femme = round(thresholds[idx_threshold_femme],4)

precisions, recalls, thresholds = precision_recall_curve(y_test_homme, y_test_proba_homme[:, 1])
idx_threshold_homme = np.argmax(recalls >= 0.95)
threshold_homme = round(thresholds[idx_threshold_homme],4)
# Out:
# np.float64(0.0769)

# %%
y_test_proba_femme = knn_clf.predict_proba(X_test_femme)

y_test_pred_femme = (y_test_proba_femme[:, 1] > threshold_femme).astype(int)

print('FEMME')
print(f"precision :  {precision_score(y_test_femme, y_test_pred_femme)}")
print(f"recall : {recall_score(y_test_femme, y_test_pred_femme)}")


y_test_proba_homme = knn_clf.predict_proba(X_test_homme)
y_test_pred_homme = (y_test_proba_homme[:, 1] > threshold_homme).astype(int)

print('------------------------------------')
print('HOMME')
print(f"precision :  {precision_score(y_test_homme, y_test_pred_homme)}")
print(f"recall : {recall_score(y_test_homme, y_test_pred_homme)}")
# Out:
# FEMME
# precision :  0.25
# recall : 1.0
# ------------------------------------
# HOMME
# precision :  0.5483870967741935
# recall : 1.0

# %% [markdown]
# The automation of discrimination through biased machine learning models is a raising concern, there are many resources of interest in the *Bibliography* section of the above article to learn about it. Be sure to check for biases in your future models !

# %% [markdown]
# # Going further : Try out other classification models

# %% [markdown]
# ## Decision Trees

# %% [markdown]
# Decision trees can be very useful when you need to understand how the classifier chooses the classes. You can read more about it there:
#
# https://en.wikipedia.org/wiki/Decision_tree_learning
#
# https://scikit-learn.org/stable/modules/tree.html

# %% [markdown]
# Train a decision tree with *max_depth=3*, and use the  sklearn.tree.plot_tree function to visualize it (use the *feature_names* and *class_names* parameters to have useful infos in the tree visualization).

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

max_depth = 3

model_tree = DecisionTreeClassifier(max_depth= max_depth)
model_tree.fit(X_train_scaled, y_train)

tree.plot_tree(model_tree, feature_names= X_train.columns, class_names=True)
# Out:
# [Text(0.5, 0.875, 'cp_0 <= 0.5\ngini = 0.496\nsamples = 212\nvalue = [115.0, 97.0]\nclass = y[0]'),
#  Text(0.25, 0.625, 'ca_0 <= 0.5\ngini = 0.328\nsamples = 116\nvalue = [92, 24]\nclass = y[0]'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'slope_1 <= 0.5\ngini = 0.49\nsamples = 35\nvalue = [20, 15]\nclass = y[0]'),
#  Text(0.0625, 0.125, 'gini = 0.32\nsamples = 20\nvalue = [16, 4]\nclass = y[0]'),
#  Text(0.1875, 0.125, 'gini = 0.391\nsamples = 15\nvalue = [4, 11]\nclass = y[1]'),
#  Text(0.375, 0.375, 'sex <= 2.745\ngini = 0.198\nsamples = 81\nvalue = [72, 9]\nclass = y[0]'),
#  Text(0.3125, 0.125, 'gini = 0.18\nsamples = 80\nvalue = [72, 8]\nclass = y[0]'),
#  Text(0.4375, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = y[1]'),
#  Text(0.75, 0.625, 'fbs <= -0.294\ngini = 0.364\nsamples = 96\nvalue = [23, 73]\nclass = y[1]'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'ca_0 <= 0.5\ngini = 0.498\nsamples = 36\nvalue = [19, 17]\nclass = y[0]'),
#  Text(0.5625, 0.125, 'gini = 0.355\nsamples = 13\nvalue = [3, 10]\nclass = y[1]'),
#  Text(0.6875, 0.125, 'gini = 0.423\nsamples = 23\nvalue = [16, 7]\nclass = y[0]'),
#  Text(0.875, 0.375, 'chol <= 1.164\ngini = 0.124\nsamples = 60\nvalue = [4, 56]\nclass = y[1]'),
#  Text(0.8125, 0.125, 'gini = 0.067\nsamples = 58\nvalue = [2, 56]\nclass = y[1]'),
#  Text(0.9375, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = y[0]')]

# %% [markdown]
# Grid search over the 'max_depth' parameter and compute the the best ROC-AUC for the decision tree:

# %%
#TOFILL

# %% [markdown]
# ## Support Vector Machines

# %% [markdown]
# In general Support Vector Machines (SVM) is the classification method that often gives the best predictive performances. You can read about it there:
#
# https://scikit-learn.org/stable/modules/svm.html (beginning of section 1.4.7 gives an intuitive view of the principles of SVMs)
#
# Similarly, grid search over the 'C' parameter and compare ROC AUC scores:

# %%
from sklearn.svm import SVC
#TOFILL

# %% [markdown]
# SVMs offer the possibility to express complex combinations of the features, through different *kernels*. See:
#
# https://scikit-learn.org/stable/auto_examples/svm/plot_svm_kernels.html
#
# https://towardsdatascience.com/understanding-support-vector-machine-part-2-kernel-trick-mercers-theorem-e1e6848c6c4d
#
# Check the available kernels in scikit-learn, and do a grid-search on kernel types and other hyper-parameters of your choice.

# %%
#TOFILL

# %% [markdown]
# ## Select the best model among all class of models and their hyper-parameters

# %% [markdown]
# Write a function that takes a list of different scikit-learn classifiers, as well as a list of each parameter grid to be searched over each classifier, and a scoring function ; and returns the best classifier along with its best parameters and its score. Finally, test it with KNN, SVM and DecisionTrees, and ensure you get a result that is consistent with the results previously obtained. You can also test with LogisticRegression, another powerful classification model.

# %%
def select_best_model_overall(classifiers_list, param_grids_list, X, y, cv=10, scoring='roc_auc'):
    #TOFILL
    
    return best_classifier, best_parameters, best_score

# %%
#TOFILL
